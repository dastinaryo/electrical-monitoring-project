# %% [markdown]
# ### Import Modul Standar

# %%
# !pip install keras==2.12.0
# !pip uninstall tensorflow
# !pip install tensorflow==2.12.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import seaborn as sns
# Out:
# ANJINGGGG :
# {
#  "date": "2022-11-19T15:26:06-0600",
#  "dirty": false,
#  "error": null,
#  "full-revisionid": "de82cd9468704a033702974010ee7e7efc85b393",
#  "version": "1.23.5"
# }
#
# ANJINGGGG :
# {
#  "date": "2022-04-02T08:46:16+0100",
#  "dirty": false,
#  "error": null,
#  "full-revisionid": "4bfe3d07b4858144c219b9346329027024102ab6",
#  "version": "1.4.2"
# }
#
# ANJINGGGG : {
#   "_version": 330,
#   "_FontManager__default_weight": "normal",
#   "default_size": null,
#   "defaultFamily": {
#     "ttf": "DejaVu Sans",
#     "afm": "Helvetica"
#   },
#   "afmlist": [
#     {
#       "fname": "fonts\\afm\\pbkdi8a.afm",
#       "name": "ITC Bookman",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "demi",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Times-BoldItalic.afm",
#       "name": "Times",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Courier.afm",
#       "name": "Courier",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pbkl8a.afm",
#       "name": "ITC Bookman",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "light",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pzdr.afm",
#       "name": "ITC Zapf Dingbats",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\ptmbi8a.afm",
#       "name": "Times",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pcrb8a.afm",
#       "name": "Courier",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pplbi8a.afm",
#       "name": "Palatino",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Times-Italic.afm",
#       "name": "Times",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pagk8a.afm",
#       "name": "ITC Avant Garde Gothic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "book",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pagd8a.afm",
#       "name": "ITC Avant Garde Gothic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "demi",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pncb8a.afm",
#       "name": "New Century Schoolbook",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Times-Roman.afm",
#       "name": "Times",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "roman",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Courier-BoldOblique.afm",
#       "name": "Courier",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pplri8a.afm",
#       "name": "Palatino",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\cmex10.afm",
#       "name": "Computer Modern",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvb8a.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Times-Bold.afm",
#       "name": "Times",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvbo8an.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\psyr.afm",
#       "name": "Symbol",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvro8a.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\putr8a.afm",
#       "name": "Utopia",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "regular",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvb8an.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvr8an.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\putbi8a.afm",
#       "name": "Utopia",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\cmsy10.afm",
#       "name": "Computer Modern",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\ptmb8a.afm",
#       "name": "Times",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\cmr10.afm",
#       "name": "Computer Modern",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Symbol.afm",
#       "name": "Symbol",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pzcmi8a.afm",
#       "name": "ITC Zapf Chancery",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pagko8a.afm",
#       "name": "ITC Avant Garde Gothic",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "book",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvlo8a.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "light",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pncr8a.afm",
#       "name": "New Century Schoolbook",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "roman",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pplr8a.afm",
#       "name": "Palatino",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "roman",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pbkd8a.afm",
#       "name": "ITC Bookman",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "demi",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvr8a.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pncri8a.afm",
#       "name": "New Century Schoolbook",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pplb8a.afm",
#       "name": "Palatino",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\ptmri8a.afm",
#       "name": "Times",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Helvetica-Oblique.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Helvetica.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\cmtt10.afm",
#       "name": "Computer Modern",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pcrro8a.afm",
#       "name": "Courier",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvl8a.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "light",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\putri8a.afm",
#       "name": "Utopia",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "regular",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvbo8a.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Helvetica-BoldOblique.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\ZapfDingbats.afm",
#       "name": "ZapfDingbats",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\ptmr8a.afm",
#       "name": "Times",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "roman",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Courier-Oblique.afm",
#       "name": "Courier",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pcrr8a.afm",
#       "name": "Courier",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pncbi8a.afm",
#       "name": "New Century Schoolbook",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\cmmi10.afm",
#       "name": "Computer Modern",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pcrbo8a.afm",
#       "name": "Courier",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Helvetica-Bold.afm",
#       "name": "Helvetica",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\phvro8an.afm",
#       "name": "Helvetica",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "medium",
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\putb8a.afm",
#       "name": "Utopia",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pagdo8a.afm",
#       "name": "ITC Avant Garde Gothic",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "demi",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\pdfcorefonts\\Courier-Bold.afm",
#       "name": "Courier",
#       "style": "normal",
#       "variant": "normal",
#       "weight": "bold",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\afm\\pbkli8a.afm",
#       "name": "ITC Bookman",
#       "style": "italic",
#       "variant": "normal",
#       "weight": "light",
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     }
#   ],
#   "ttflist": [
#     {
#       "fname": "fonts\\ttf\\DejaVuSans-Oblique.ttf",
#       "name": "DejaVu Sans",
#       "style": "oblique",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSansDisplay.ttf",
#       "name": "DejaVu Sans Display",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSerif-Italic.ttf",
#       "name": "DejaVu Serif",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmss10.ttf",
#       "name": "cmss10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSans-Bold.ttf",
#       "name": "DejaVu Sans",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmr10.ttf",
#       "name": "cmr10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSerifDisplay.ttf",
#       "name": "DejaVu Serif Display",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXGeneralBol.ttf",
#       "name": "STIXGeneral",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmtt10.ttf",
#       "name": "cmtt10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizTwoSymBol.ttf",
#       "name": "STIXSizeTwoSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXGeneral.ttf",
#       "name": "STIXGeneral",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizFourSymReg.ttf",
#       "name": "STIXSizeFourSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmsy10.ttf",
#       "name": "cmsy10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizOneSymBol.ttf",
#       "name": "STIXSizeOneSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizFiveSymReg.ttf",
#       "name": "STIXSizeFiveSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmex10.ttf",
#       "name": "cmex10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSans.ttf",
#       "name": "DejaVu Sans",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXGeneralBolIta.ttf",
#       "name": "STIXGeneral",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSansMono.ttf",
#       "name": "DejaVu Sans Mono",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmb10.ttf",
#       "name": "cmb10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizTwoSymReg.ttf",
#       "name": "STIXSizeTwoSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXGeneralItalic.ttf",
#       "name": "STIXGeneral",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXNonUniBol.ttf",
#       "name": "STIXNonUnicode",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizThreeSymBol.ttf",
#       "name": "STIXSizeThreeSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSerif-Bold.ttf",
#       "name": "DejaVu Serif",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXNonUniIta.ttf",
#       "name": "STIXNonUnicode",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSansMono-Bold.ttf",
#       "name": "DejaVu Sans Mono",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSansMono-BoldOblique.ttf",
#       "name": "DejaVu Sans Mono",
#       "style": "oblique",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSansMono-Oblique.ttf",
#       "name": "DejaVu Sans Mono",
#       "style": "oblique",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSerif.ttf",
#       "name": "DejaVu Serif",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSerif-BoldItalic.ttf",
#       "name": "DejaVu Serif",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXNonUniBolIta.ttf",
#       "name": "STIXNonUnicode",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\DejaVuSans-BoldOblique.ttf",
#       "name": "DejaVu Sans",
#       "style": "oblique",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXNonUni.ttf",
#       "name": "STIXNonUnicode",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\cmmi10.ttf",
#       "name": "cmmi10",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizThreeSymReg.ttf",
#       "name": "STIXSizeThreeSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizFourSymBol.ttf",
#       "name": "STIXSizeFourSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "fonts\\ttf\\STIXSizOneSymReg.ttf",
#       "name": "STIXSizeOneSym",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\Candarai.ttf",
#       "name": "Candara",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\comicbd.ttf",
#       "name": "Comic Sans MS",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\VINERITC.TTF",
#       "name": "Viner Hand ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0050m_.ttf",
#       "name": "NewsGoth BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt6807m_.ttf",
#       "name": "CentSchbkCyrill BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\calibri.ttf",
#       "name": "Calibri",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0102m_.ttf",
#       "name": "Swis721 Hv BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\AdobeMyungjoStd-Medium.otf",
#       "name": "Adobe Myungjo Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 500,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\FTLTLT.TTF",
#       "name": "Footlight MT Light",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\PERB____.TTF",
#       "name": "Perpetua",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\TCM_____.TTF",
#       "name": "Tw Cen MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\corbeli.ttf",
#       "name": "Corbel",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\ERASDEMI.TTF",
#       "name": "Eras Demi ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\georgiaz.ttf",
#       "name": "Georgia",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\webdings.ttf",
#       "name": "Webdings",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0292m_.ttf",
#       "name": "Humanst521 BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\ACaslonPro-SemiboldItalic.otf",
#       "name": "Adobe Caslon Pro",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 600,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\consola.ttf",
#       "name": "Consolas",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\TEMPSITC.TTF",
#       "name": "Tempus Sans ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\GOUDOSI.TTF",
#       "name": "Goudy Old Style",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\LBRITEDI.TTF",
#       "name": "Lucida Bright",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 600,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\PERI____.TTF",
#       "name": "Perpetua",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\TektonPro-BoldExt.otf",
#       "name": "Tekton Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "expanded",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\DejaVuSansMono.ttf",
#       "name": "DejaVu Sans Mono",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\Gabriola.ttf",
#       "name": "Gabriola",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\consolaz.ttf",
#       "name": "Consolas",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\himalaya.ttf",
#       "name": "Microsoft Himalaya",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\BSSYM7.TTF",
#       "name": "Bookshelf Symbol 7",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\MyriadArabic-Regular.otf",
#       "name": "Myriad Arabic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MyriadPro-CondIt.otf",
#       "name": "Myriad Pro",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\ELEPHNTI.TTF",
#       "name": "Elephant",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\cambriaz.ttf",
#       "name": "Cambria",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\AdobeMingStd-Light.otf",
#       "name": "Adobe Ming Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\segoeuib.ttf",
#       "name": "Segoe UI",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\calibriz.ttf",
#       "name": "Calibri",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\TEMPSITC.TTF",
#       "name": "Tempus Sans ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\Candaral.ttf",
#       "name": "Candara",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\COLONNA.TTF",
#       "name": "Colonna MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0037m_.ttf",
#       "name": "Bodoni Bd BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\KozGoPro-Bold.otf",
#       "name": "Kozuka Gothic Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\AdobeMingStd-Light.otf",
#       "name": "Adobe Ming Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt1185m_.ttf",
#       "name": "Century751 No2 BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt1159m_.ttf",
#       "name": "Humnst777 Cn BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\GILB____.TTF",
#       "name": "Gill Sans MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0869m_.ttf",
#       "name": "Century751 BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\corbel.ttf",
#       "name": "Corbel",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\CALIFI.TTF",
#       "name": "Californian FB",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Users\\ACER\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Amatic-Bold.ttf",
#       "name": "Amatic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\KozMinPro-ExtraLight.otf",
#       "name": "Kozuka Mincho Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 250,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\ERASDEMI.TTF",
#       "name": "Eras Demi ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\LHANDW.TTF",
#       "name": "Lucida Handwriting",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Users\\ACER\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Quicksand_Light_Oblique.otf",
#       "name": "Quicksand",
#       "style": "oblique",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0006c_.ttf",
#       "name": "Swis721 WGL4 BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\cour.ttf",
#       "name": "Courier New",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\KozGoPro-Medium.otf",
#       "name": "Kozuka Gothic Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 500,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MyriadHebrew-It.otf",
#       "name": "Myriad Hebrew",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\MyriadPro-Semibold.otf",
#       "name": "Myriad Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 600,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0375m_.ttf",
#       "name": "NewsGoth Cn BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\ITCKRIST.TTF",
#       "name": "Kristen ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\msjh.ttc",
#       "name": "Microsoft JhengHei",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\KozGoPr6N-Regular.otf",
#       "name": "Kozuka Gothic Pr6N",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\seguisli.ttf",
#       "name": "Segoe UI",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 350,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\GILI____.TTF",
#       "name": "Gill Sans MT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\TrajanPro-Regular.otf",
#       "name": "Trajan Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\LithosPro-Regular.otf",
#       "name": "Lithos Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\KozGoPr6N-ExtraLight.otf",
#       "name": "Kozuka Gothic Pr6N",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 250,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\courbd.ttf",
#       "name": "Courier New",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\tt0001m_.ttf",
#       "name": "Swis721 Lt BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\NuevaStd-BoldCondItalic.otf",
#       "name": "Nueva Std",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\CooperBlackStd-Italic.otf",
#       "name": "Cooper Std",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 900,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\CALISTB.TTF",
#       "name": "Calisto MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\KozGoPro-ExtraLight.otf",
#       "name": "Kozuka Gothic Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 250,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\STENCIL.TTF",
#       "name": "Stencil",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\himalaya.ttf",
#       "name": "Microsoft Himalaya",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\JOKERMAN.TTF",
#       "name": "Jokerman",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\KozMinPr6N-ExtraLight.otf",
#       "name": "Kozuka Mincho Pr6N",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 250,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\tt6804m_.ttf",
#       "name": "CentSchbkCyrill BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\tt0868m_.ttf",
#       "name": "Century751 BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\AdobeHeitiStd-Regular.otf",
#       "name": "Adobe Heiti Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\wingding.ttf",
#       "name": "Wingdings",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\TCCM____.TTF",
#       "name": "Tw Cen MT Condensed",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\BRADHITC.TTF",
#       "name": "Bradley Hand ITC",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\CharlemagneStd-Bold.otf",
#       "name": "Charlemagne Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\COPRGTB.TTF",
#       "name": "Copperplate Gothic Bold",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\DFMinE1.ttf",
#       "name": "DFMincho-SU",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MyriadArabic-Regular.otf",
#       "name": "Myriad Arabic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\NuevaStd-BoldCond.otf",
#       "name": "Nueva Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\gadugib.ttf",
#       "name": "Gadugi",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\DUBAI-LIGHT.TTF",
#       "name": "Dubai",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\PoplarStd.otf",
#       "name": "Poplar Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0049m_.ttf",
#       "name": "NewsGoth BT",
#       "style": "normal",
# ...
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0588m_.ttf",
#       "name": "Embassy BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\COPRGTL.TTF",
#       "name": "Copperplate Gothic Light",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\l_10646.ttf",
#       "name": "Lucida Sans Unicode",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\CALIST.TTF",
#       "name": "Calisto MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\tt0005m_.ttf",
#       "name": "Swis721 BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt1184m_.ttf",
#       "name": "Century751 No2 BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\PALSCRI.TTF",
#       "name": "Palace Script MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\seguisli.ttf",
#       "name": "Segoe UI",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 350,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\trebucit.ttf",
#       "name": "Trebuchet MS",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\DUBAI-MEDIUM.TTF",
#       "name": "Dubai",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 500,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Users\\ACER\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Quicksand_Bold_Oblique.otf",
#       "name": "Quicksand",
#       "style": "oblique",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\BAUHS93.TTF",
#       "name": "Bauhaus 93",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\GARA.TTF",
#       "name": "Garamond",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\ANTQUABI.TTF",
#       "name": "Book Antiqua",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\RAGE.TTF",
#       "name": "Rage Italic",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0726m_.ttf",
#       "name": "Kaufmann BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\Inkfree.ttf",
#       "name": "Ink Free",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0047m_.ttf",
#       "name": "NewsGoth BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\pala.ttf",
#       "name": "Palatino Linotype",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\LSANSI.TTF",
#       "name": "Lucida Sans",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\ROCKB.TTF",
#       "name": "Rockwell",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MyriadPro-Regular.otf",
#       "name": "Myriad Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MinionPro-SemiboldIt.otf",
#       "name": "Minion Pro",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 600,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\Candaraz.ttf",
#       "name": "Candara",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\AdobeArabic-Bold.otf",
#       "name": "Adobe Arabic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\LBRITED.TTF",
#       "name": "Lucida Bright",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 600,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\FRABK.TTF",
#       "name": "Franklin Gothic Book",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\segoeprb.ttf",
#       "name": "Segoe Print",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\phagspab.ttf",
#       "name": "Microsoft PhagsPa",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\LSANSI.TTF",
#       "name": "Lucida Sans",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0173m_.ttf",
#       "name": "Swis721 BlkCn BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt0291m_.ttf",
#       "name": "Humanst521 BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\FRAHVIT.TTF",
#       "name": "Franklin Gothic Heavy",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\DejaVuSerif.ttf",
#       "name": "DejaVu Serif",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\calibril.ttf",
#       "name": "Calibri",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\MISTRAL.TTF",
#       "name": "Mistral",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\AGENCYR.TTF",
#       "name": "Agency FB",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\AGaramondPro-Italic.otf",
#       "name": "Adobe Garamond Pro",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\tt1160m_.ttf",
#       "name": "Humnst777 Cn BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\MyriadPro-Cond.otf",
#       "name": "Myriad Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\seguihis.ttf",
#       "name": "Segoe UI Historic",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\LetterGothicStd-BoldSlanted.otf",
#       "name": "Letter Gothic Std",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MyriadArabic-BoldIt.otf",
#       "name": "Myriad Arabic",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\NirmalaS.ttf",
#       "name": "Nirmala UI",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 350,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Users\\ACER\\AppData\\Local\\Microsoft\\Windows\\Fonts\\Brown Pen.ttf",
#       "name": "Brown Pen",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\LetterGothicStd-Bold.otf",
#       "name": "Letter Gothic Std",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\CURLZ___.TTF",
#       "name": "Curlz MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\tt0289m_.ttf",
#       "name": "Humanst521 Lt BT",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\MISTRAL.TTF",
#       "name": "Mistral",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\KozMinPr6N-Light.otf",
#       "name": "Kozuka Mincho Pr6N",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\OLDENGL.TTF",
#       "name": "Old English Text MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\seguisym.ttf",
#       "name": "Segoe UI Symbol",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\AdobeHebrew-Bold.otf",
#       "name": "Adobe Hebrew",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 600,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\TCM_____.TTF",
#       "name": "Tw Cen MT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\MyriadPro-Bold.otf",
#       "name": "Myriad Pro",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\tt0504m_.ttf",
#       "name": "Geometr212 BkCn BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\OCR-a___.ttf",
#       "name": "OCR-A BT",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\Windows\\Fonts\\HARNGTON.TTF",
#       "name": "Harrington",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\DFKai71.ttf",
#       "name": "DFKaiSho-SB",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 400,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\MyriadPro-BoldCondIt.otf",
#       "name": "Myriad Pro",
#       "style": "italic",
#       "variant": "normal",
#       "weight": 700,
#       "stretch": "condensed",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     },
#     {
#       "fname": "C:\\WINDOWS\\Fonts\\BOOKOS.TTF",
#       "name": "Bookman Old Style",
#       "style": "normal",
#       "variant": "normal",
#       "weight": 300,
#       "stretch": "normal",
#       "size": "scalable",
#       "__class__": "FontEntry"
#     }
#   ],
#   "__class__": "FontManager"
# }
# ANJINGGGG : {"date":"2024-04-25T06:41:53.687Z","msg_id":"6d11fec5-8e67-4fae-bbf3-b41359c6e3bb","msg_type":"comm_info_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {}
# ANJINGGGG : {"target_name":"jupyter.widget"}

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import json
# %matplotlib inline
# import seaborn as sns
# sns.set_theme(style="whitegrid")
# import warnings
# warnings.filterwarnings("ignore")

# %%
import json

# Buka file JSON
with open('database_fix_non-anomally.json') as file:
    data = json.load(file)
# Out:
# ANJINGGGG : {
#     "collection_data": {
#         "electricity_data": {
#             "01-12-2023": {
#                 "biaya": 5042.0,
#                 "daya": 2200,
#                 "kwh": 3.49,
#                 "timestamp": "23:59:50"
#             },
#             "02-12-2023": {
#                 "biaya": 5518.75,
#                 "daya": 2200,
#                 "kwh": 3.82,
#                 "timestamp": "23:59:50"
#             },
#             "03-12-2023": {
#                 "biaya": 6255.55,
#                 "daya": 2200,
#                 "kwh": 4.33,
#                 "timestamp": "23:59:50"
#             },
#             "04-12-2023": {
#                 "biaya": 2051.47,
#                 "daya": 2200,
#                 "kwh": 1.42,
#                 "timestamp": "23:59:50"
#             },
#             "05-12-2023": {
#                 "biaya": 2903.85,
#                 "daya": 2200,
#                 "kwh": 2.01,
#                 "timestamp": "23:59:50"
#             },
#             "06-12-2023": {
#                 "biaya": 3510.62,
#                 "daya": 2200,
#                 "kwh": 2.43,
#                 "timestamp": "23:59:50"
#             },
#             "07-12-2023": {
#                 "biaya": 4146.29,
#                 "daya": 2200,
#                 "kwh": 2.87,
#                 "timestamp": "23:59:50"
#             },
#             "08-12-2023": {
#                 "biaya": 5070.9,
#                 "daya": 2200,
#                 "kwh": 3.51,
#                 "timestamp": "23:59:50"
#             },
#             "09-12-2023": {
#                 "biaya": 5619.88,
#                 "daya": 2200,
#                 "kwh": 3.89,
#                 "timestamp": "23:59:50"
#             },
#             "10-12-2023": {
#                 "biaya": 6371.13,
#                 "daya": 2200,
#                 "kwh": 4.41,
#                 "timestamp": "23:59:50"
#             },
#             "11-12-2023": {
#                 "biaya": 2008.13,
#                 "daya": 2200,
#                 "kwh": 1.39,
#                 "timestamp": "23:59:50"
#             },
#             "12-12-2023": {
#                 "biaya": 3062.76,
#                 "daya": 2200,
#                 "kwh": 2.12,
#                 "timestamp": "23:59:50"
#             },
#             "13-12-2023": {
#                 "biaya": 3683.98,
#                 "daya": 2200,
#                 "kwh": 2.55,
#                 "timestamp": "23:59:50"
#             },
#             "14-12-2023": {
#                 "biaya": 4204.08,
#                 "daya": 2200,
#                 "kwh": 2.91,
#                 "timestamp": "23:59:50"
#             },
#             "15-12-2023": {
#                 "biaya": 4998.66,
#                 "daya": 2200,
#                 "kwh": 3.46,
#                 "timestamp": "23:59:50"
#             },
#             "16-12-2023": {
#                 "biaya": 5605.44,
#                 "daya": 2200,
#                 "kwh": 3.88,
#                 "timestamp": "23:59:50"
#             },
#             "17-12-2023": {
#                 "biaya": 6226.66,
#                 "daya": 2200,
#                 "kwh": 4.31,
#                 "timestamp": "23:59:50"
#             },
#             "18-12-2023": {
#                 "biaya": 2138.16,
#                 "daya": 2200,
#                 "kwh": 1.48,
#                 "timestamp": "23:59:50"
#             },
#             "19-12-2023": {
#                 "biaya": 3149.45,
#                 "daya": 2200,
#                 "kwh": 2.18,
#                 "timestamp": "23:59:50"
#             },
#             "20-12-2023": {
#                 "biaya": 3712.88,
#                 "daya": 2200,
#                 "kwh": 2.57,
#                 "timestamp": "23:59:50"
#             },
#             "21-12-2023": {
#                 "biaya": 4204.08,
#                 "daya": 2200,
#                 "kwh": 2.91,
#                 "timestamp": "23:59:50"
#             },
#             "22-12-2023": {
#                 "biaya": 5042.0,
#                 "daya": 2200,
#                 "kwh": 3.49,
#                 "timestamp": "23:59:50"
#             },
#             "23-12-2023": {
#                 "biaya": 5764.35,
#                 "daya": 2200,
#                 "kwh": 3.99,
#                 "timestamp": "23:59:50"
#             },
#             "24-12-2023": {
#                 "biaya": 6414.47,
#                 "daya": 2200,
#                 "kwh": 4.44,
#                 "timestamp": "23:59:50"
#             },
#             "25-12-2023": {
#                 "biaya": 2181.5,
#                 "daya": 2200,
#                 "kwh": 1.51,
#                 "timestamp": "23:59:50"
#             },
#             "26-12-2023": {
#                 "biaya": 3163.89,
#                 "daya": 2200,
#                 "kwh": 2.19,
#                 "timestamp": "23:59:50"
#             },
#             "27-12-2023": {
#                 "biaya": 3727.33,
#                 "daya": 2200,
#                 "kwh": 2.58,
#                 "timestamp": "23:59:50"
#             },
#             "28-12-2023": {
#                 "biaya": 4146.29,
#                 "daya": 2200,
#                 "kwh": 2.87,
#                 "timestamp": "23:59:50"
#             },
#             "29-12-2023": {
#                 "biaya": 5143.13,
#                 "daya": 2200,
#                 "kwh": 3.56,
#                 "timestamp": "23:59:50"
#             },
#             "30-12-2023": {
#                 "biaya": 5576.54,
#                 "daya": 2200,
#                 "kwh": 3.86,
#                 "timestamp": "23:59:50"
#             },
#             "31-12-2023": {
#                 "biaya": 6197.76,
#                 "daya": 2200,
#                 "kwh": 4.29,
#                 "timestamp": "23:59:50"
#             },
#             "01-01-2024": {
#                 "biaya": 2094.82,
#                 "daya": 2200,
#                 "kwh": 1.45,
#                 "timestamp": "23:59:50"
#             },
#             "02-01-2024": {
#                 "biaya": 3135.0,
#                 "daya": 2200,
#                 "kwh": 2.17,
#                 "timestamp": "23:59:50"
#             },
#             "03-01-2024": {
#                 "biaya": 3452.83,
#                 "daya": 2200,
#                 "kwh": 2.39,
#                 "timestamp": "23:59:50"
#             },
#             "04-01-2024": {
#                 "biaya": 4146.29,
#                 "daya": 2200,
#                 "kwh": 2.87,
#                 "timestamp": "23:59:50"
#             },
#             "05-01-2024": {
#                 "biaya": 5042.0,
#                 "daya": 2200,
#                 "kwh": 3.49,
#                 "timestamp": "23:59:50"
#             },
#             "06-01-2024": {
#                 "biaya": 5692.12,
#                 "daya": 2200,
#                 "kwh": 3.94,
#                 "timestamp": "23:59:50"
#             },
#             "07-01-2024": {
#                 "biaya": 6241.1,
#                 "daya": 2200,
#                 "kwh": 4.32,
#                 "timestamp": "23:59:50"
#             },
#             "08-01-2024": {
#                 "biaya": 2210.39,
#                 "daya": 2200,
#                 "kwh": 1.53,
#                 "timestamp": "23:59:50"
#             },
#             "09-01-2024": {
#                 "biaya": 3135.0,
#                 "daya": 2200,
#                 "kwh": 2.17,
#                 "timestamp": "23:59:50"
#             },
#             "10-01-2024": {
#                 "biaya": 3640.64,
#                 "daya": 2200,
#                 "kwh": 2.52,
#                 "timestamp": "23:59:50"
#             },
#             "11-01-2024": {
#                 "biaya": 4232.97,
#                 "daya": 2200,
#                 "kwh": 2.93,
#                 "timestamp": "23:59:50"
#             },
#             "12-01-2024": {
#                 "biaya": 5172.03,
#                 "daya": 2200,
#                 "kwh": 3.58,
#                 "timestamp": "23:59:50"
#             },
#             "13-01-2024": {
#                 "biaya": 5677.67,
#                 "daya": 2200,
#                 "kwh": 3.93,
#                 "timestamp": "23:59:50"
#             },
#             "14-01-2024": {
#                 "biaya": 6284.44,
#                 "daya": 2200,
#                 "kwh": 4.35,
#                 "timestamp": "23:59:50"
#             },
#             "15-01-2024": {
#                 "biaya": 2282.63,
#                 "daya": 2200,
#                 "kwh": 1.58,
#                 "timestamp": "23:59:50"
#             },
#             "16-01-2024": {
#                 "biaya": 3062.76,
#                 "daya": 2200,
#                 "kwh": 2.12,
#                 "timestamp": "23:59:50"
#             },
#             "17-01-2024": {
#                 "biaya": 3525.07,
#                 "daya": 2200,
#                 "kwh": 2.44,
#                 "timestamp": "23:59:50"
#             },
#             "18-01-2024": {
#                 "biaya": 4074.05,
#                 "daya": 2200,
#                 "kwh": 2.82,
#                 "timestamp": "23:59:50"
#             },
#             "19-01-2024": {
#                 "biaya": 5042.0,
#                 "daya": 2200,
#                 "kwh": 3.49,
#                 "timestamp": "23:59:50"
#             },
#             "20-01-2024": {
#                 "biaya": 5706.57,
#                 "daya": 2200,
#                 "kwh": 3.95,
#                 "timestamp": "23:59:50"
#             },
#             "21-01-2024": {
#                 "biaya": 6327.79,
#                 "daya": 2200,
#                 "kwh": 4.38,
#                 "timestamp": "23:59:50"
#             },
#             "22-01-2024": {
#                 "biaya": 2051.47,
#                 "daya": 2200,
#                 "kwh": 1.42,
#                 "timestamp": "23:59:50"
#             },
#             "23-01-2024": {
#                 "biaya": 3048.32,
#                 "daya": 2200,
#                 "kwh": 2.11,
#                 "timestamp": "23:59:50"
#             },
#             "24-01-2024": {
#                 "biaya": 3683.98,
#                 "daya": 2200,
#                 "kwh": 2.55,
#                 "timestamp": "23:59:50"
#             },
#             "25-01-2024": {
#                 "biaya": 4204.08,
#                 "daya": 2200,
#                 "kwh": 2.91,
#                 "timestamp": "23:59:50"
#             },
#             "26-01-2024": {
#                 "biaya": 4940.87,
#                 "daya": 2200,
#                 "kwh": 3.42,
#                 "timestamp": "23:59:50"
#             },
#             "27-01-2024": {
#                 "biaya": 5605.44,
#                 "daya": 2200,
#                 "kwh": 3.88,
#                 "timestamp": "23:59:50"
#             },
#             "28-01-2024": {
#                 "biaya": 6096.63,
#                 "daya": 2200,
#                 "kwh": 4.22,
#                 "timestamp": "23:59:50"
#             },
#             "29-01-2024": {
#                 "biaya": 2037.03,
#                 "daya": 2200,
#                 "kwh": 1.41,
#                 "timestamp": "23:59:50"
#             },
#             "30-01-2024": {
#                 "biaya": 3135.0,
#                 "daya": 2200,
#                 "kwh": 2.17,
#                 "timestamp": "23:59:50"
#             },
#             "31-01-2024": {
#                 "biaya": 3698.43,
#                 "daya": 2200,
#                 "kwh": 2.56,
#                 "timestamp": "23:59:50"
#             },
#             "01-02-2024": {
#                 "biaya": 4305.21,
#                 "daya": 2200,
#                 "kwh": 2.98,
#                 "timestamp": "23:59:50"
#             },
#             "02-02-2024": {
#                 "biaya": 5215.37,
#                 "daya": 2200,
#                 "kwh": 3.61,
#                 "timestamp": "23:59:50"
#             },
#             "03-02-2024": {
#                 "biaya": 5735.46,
#                 "daya": 2200,
#                 "kwh": 3.97,
#                 "timestamp": "23:59:50"
#             },
#             "04-02-2024": {
#                 "biaya": 6226.66,
#                 "daya": 2200,
#                 "kwh": 4.31,
#                 "timestamp": "23:59:50"
#             },
#             "05-02-2024": {
#                 "biaya": 2051.47,
#                 "daya": 2200,
#                 "kwh": 1.42,
#                 "timestamp": "23:59:50"
#             },
#             "06-02-2024": {
#                 "biaya": 3135.0,
#                 "daya": 2200,
#                 "kwh": 2.17,
#                 "timestamp": "23:59:50"
#             },
#             "07-02-2024": {
#                 "biaya": 3481.73,
#                 "daya": 2200,
#                 "kwh": 2.41,
#                 "timestamp": "23:59:50"
#             },
#             "08-02-2024": {
#                 "biaya": 4204.08,
#                 "daya": 2200,
#                 "kwh": 2.91,
#                 "timestamp": "23:59:50"
#             },
#             "09-02-2024": {
#                 "biaya": 5070.9,
#                 "daya": 2200,
#                 "kwh": 3.51,
#                 "timestamp": "23:59:50"
#             },
#             "10-02-2024": {
#                 "biaya": 5590.99,
#                 "daya": 2200,
#                 "kwh": 3.87,
#                 "timestamp": "23:59:50"
#             },
#             "11-02-2024": {
#                 "biaya": 6226.66,
#                 "daya": 2200,
#                 "kwh": 4.31,
#                 "timestamp": "23:59:50"
#             },
#             "12-02-2024": {
#                 "biaya": 2051.47,
#                 "daya": 2200,
#                 "kwh": 1.42,
#                 "timestamp": "23:59:50"
#             },
#             "13-02-2024": {
#                 "biaya": 3048.32,
#                 "daya": 2200,
#                 "kwh": 2.11,
#                 "timestamp": "23:59:50"
#             },
#             "14-02-2024": {
#                 "biaya": 3626.2,
#                 "daya": 2200,
#                 "kwh": 2.51,
#                 "timestamp": "23:59:50"
#             },
#             "15-02-2024": {
#                 "biaya": 4305.21,
#                 "daya": 2200,
#                 "kwh": 2.98,
#                 "timestamp": "23:59:50"
#             },
#             "16-02-2024": {
#                 "biaya": 4940.87,
#                 "daya": 2200,
#                 "kwh": 3.42,
#                 "timestamp": "23:59:50"
#             },
#             "17-02-2024": {
#                 "biaya": 5648.78,
#                 "daya": 2200,
#                 "kwh": 3.91,
#                 "timestamp": "23:59:50"
#             },
#             "18-02-2024": {
#                 "biaya": 6457.81,
#                 "daya": 2200,
#                 "kwh": 4.47,
#                 "timestamp": "23:59:50"
#             },
#             "19-02-2024": {
#                 "biaya": 2008.13,
#                 "daya": 2200,
#                 "kwh": 1.39,
#                 "timestamp": "23:59:50"
#             },
#             "20-02-2024": {
#                 "biaya": 3062.76,
#                 "daya": 2200,
#                 "kwh": 2.12,
#                 "timestamp": "23:59:50"
#             },
#             "21-02-2024": {
#                 "biaya": 3481.73,
#                 "daya": 2200,
#                 "kwh": 2.41,
#                 "timestamp": "23:59:50"
#             },
#             "22-02-2024": {
#                 "biaya": 4146.29,
#                 "daya": 2200,
#                 "kwh": 2.87,
#                 "timestamp": "23:59:50"
#             },
#             "23-02-2024": {
#                 "biaya": 5143.13,
#                 "daya": 2200,
#                 "kwh": 3.56,
#                 "timestamp": "23:59:50"
#             },
#             "24-02-2024": {
#                 "biaya": 5749.91,
#                 "daya": 2200,
#                 "kwh": 3.98,
#                 "timestamp": "23:59:50"
#             },
#             "25-02-2024": {
#                 "biaya": 6226.66,
#                 "daya": 2200,
#                 "kwh": 4.31,
#                 "timestamp": "23:59:50"
#             },
#             "26-02-2024": {
#                 "biaya": 2123.71,
#                 "daya": 2200,
#                 "kwh": 1.47,
#                 "timestamp": "23:59:50"
#             },
#             "27-02-2024": {
#                 "biaya": 3048.32,
#                 "daya": 2200,
#                 "kwh": 2.11,
#                 "timestamp": "23:59:50"
#             },
#             "28-02-2024": {
#                 "biaya": 3640.64,
#                 "daya": 2200,
#                 "kwh": 2.52,
#                 "timestamp": "23:59:50"
#             },
#             "29-02-2024": {
#                 "biaya": 4175.18,
#                 "daya": 2200,
#                 "kwh": 2.89,
#                 "timestamp": "23:59:50"
#             },
#             "01-03-2024": {
#                 "biaya": 5172.03,
#                 "daya": 2200,
#                 "kwh": 3.58,
#                 "timestamp": "23:59:50"
#             },
#             "02-03-2024": {
#                 "biaya": 5518.75,
#                 "daya": 2200,
#                 "kwh": 3.82,
#                 "timestamp": "23:59:50"
#             },
#             "03-03-2024": {
#                 "biaya": 6270.0,
#                 "daya": 2200,
#                 "kwh": 4.34,
#                 "timestamp": "23:59:50"
#             },
#             "04-03-2024": {
#                 "biaya": 2195.94,
#                 "daya": 2200,
#                 "kwh": 1.52,
#                 "timestamp": "23:59:50"
#             },
#             "05-03-2024": {
#                 "biaya": 3077.21,
#                 "daya": 2200,
#                 "kwh": 2.13,
#                 "timestamp": "23:59:50"
#             },
#             "06-03-2024": {
#                 "biaya": 3496.17,
#                 "daya": 2200,
#                 "kwh": 2.42,
#                 "timestamp": "23:59:50"
#             },
#             "07-03-2024": {
#                 "biaya": 4261.87,
#                 "daya": 2200,
#                 "kwh": 2.95,
#                 "timestamp": "23:59:50"
#             },
#             "08-03-2024": {
#                 "biaya": 5027.56,
#                 "daya": 2200,
#                 "kwh": 3.48,
#                 "timestamp": "23:59:50"
#             },
#             "09-03-2024": {
#                 "biaya": 5677.67,
#                 "daya": 2200,
#                 "kwh": 3.93,
#                 "timestamp": "23:59:50"
#             },
#             "10-03-2024": {
#                 "biaya": 6371.13,
#                 "daya": 2200,
#                 "kwh": 4.41,
#                 "timestamp": "23:59:50"
#             },
#             "11-03-2024": {
#                 "biaya": 2008.13,
#                 "daya": 2200,
#                 "kwh": 1.39,
#                 "timestamp": "23:59:50"
#             },
#             "12-03-2024": {
#                 "biaya": 3120.55,
#                 "daya": 2200,
#                 "kwh": 2.16,
#                 "timestamp": "23:59:50"
#             },
#             "13-03-2024": {
#                 "biaya": 3669.54,
#                 "daya": 2200,
#                 "kwh": 2.54,
#                 "timestamp": "23:59:50"
#             },
#             "14-03-2024": {
#                 "biaya": 4290.76,
#                 "daya": 2200,
#                 "kwh": 2.97,
#                 "timestamp": "23:59:50"
#             },
#             "15-03-2024": {
#                 "biaya": 5042.0,
#                 "daya": 2200,
#                 "kwh": 3.49,
#                 "timestamp": "23:59:50"
#             },
#             "16-03-2024": {
#                 "biaya": 5619.88,
#                 "daya": 2200,
#                 "kwh": 3.89,
#                 "timestamp": "23:59:50"
#             },
#             "17-03-2024": {
#                 "biaya": 6270.0,
#                 "daya": 2200,
#                 "kwh": 4.34,
#                 "timestamp": "23:59:50"
#             },
#             "18-03-2024": {
#                 "biaya": 2008.13,
#                 "daya": 2200,
#                 "kwh": 1.39,
#                 "timestamp": "23:59:50"
#             },
#             "19-03-2024": {
#                 "biaya": 3077.21,
#                 "daya": 2200,
#                 "kwh": 2.13,
#                 "timestamp": "23:59:50"
#             },
#             "20-03-2024": {
#                 "biaya": 3597.3,
#                 "daya": 2200,
#                 "kwh": 2.49,
#                 "timestamp": "23:59:50"
#             },
#             "21-03-2024": {
#                 "biaya": 4175.18,
#                 "daya": 2200,
#                 "kwh": 2.89,
#                 "timestamp": "23:59:50"
#             },
#             "22-03-2024": {
#                 "biaya": 5114.24,
#                 "daya": 2200,
#                 "kwh": 3.54,
#                 "timestamp": "23:59:50"
#             },
#             "23-03-2024": {
#                 "biaya": 5533.2,
#                 "daya": 2200,
#                 "kwh": 3.83,
#                 "timestamp": "23:59:50"
#             },
#             "24-03-2024": {
#                 "biaya": 6255.55,
#                 "daya": 2200,
#                 "kwh": 4.33,
#                 "timestamp": "23:59:50"
#             },
#             "25-03-2024": {
#                 "biaya": 2181.5,
#                 "daya": 2200,
#                 "kwh": 1.51,
#                 "timestamp": "23:59:50"
#             },
#             "26-03-2024": {
#                 "biaya": 3135.0,
#                 "daya": 2200,
#                 "kwh": 2.17,
#                 "timestamp": "23:59:50"
#             },
#             "27-03-2024": {
#                 "biaya": 3698.43,
#                 "daya": 2200,
#                 "kwh": 2.56,
#                 "timestamp": "23:59:50"
#             },
#             "28-03-2024": {
#                 "biaya": 4218.52,
#                 "daya": 2200,
#                 "kwh": 2.92,
#                 "timestamp": "23:59:50"
#             },
#             "29-03-2024": {
#                 "biaya": 5070.9,
#                 "daya": 2200,
#                 "kwh": 3.51,
#                 "timestamp": "23:59:50"
#             },
#             "30-03-2024": {
#                 "biaya": 5590.99,
#                 "daya": 2200,
#                 "kwh": 3.87,
#                 "timestamp": "23:59:50"
#             },
#             "31-03-2024": {
#                 "biaya": 6226.66,
#                 "daya": 2200,
#                 "kwh": 4.31,
#                 "timestamp": "23:59:50"
#             }
#         },
#         "tokenizer": {
#             "remaining_token_balance": "1234",
#             "stroom_token": "213432432423"
#         }
#     }
# }
# ANJINGGGG : {"date":"2024-04-25T06:42:18.866Z","msg_id":"bc7ec047-c960-446c-82de-a24f4cff7f96","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":
}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"import pandas as pd\n\n# Data yang akan diubah menjadi DataFrame\ndatabase = []\nfor i in data['collection_data']['electricity_data']:\n  database.append({i:data['collection_data']['electricity_data'][i]})\n\ndfs = []\n\n# Loop melalui setiap elemen dictionary di dalam list\nfor item in database:\n    for date, values in item.items():\n        # Menambahkan tanggal ke dictionary\n        values['tanggal'] = date\n        # Mengubah dictionary menjadi DataFrame dan menambahkannya ke list dfs\n        df = pd.DataFrame([values])\n        dfs.append(df)\n\n# Menggabungkan semua DataFrame menjadi satu DataFrame besar\nmerged_df = pd.concat(dfs, ignore_index=True)\n\n# Mengatur ulang urutan kolom\nmerged_df = merged_df[['tanggal', 'biaya', 'daya', 'kwh', 'timestamp']]\nmerged_df['tanggal'] = pd.to_datetime(merged_df['tanggal'], format='%d-%m-%Y')\n# merged_df['tanggal'] = merged_df['tanggal'].astype('datetime64')\n\n\n# Tampilkan DataFrame\ndf=merged_df\ndf"}

# %%
import pandas as pd

# Data yang akan diubah menjadi DataFrame
database = []
for i in data['collection_data']['electricity_data']:
  database.append({i:data['collection_data']['electricity_data'][i]})

dfs = []

# Loop melalui setiap elemen dictionary di dalam list
for item in database:
    for date, values in item.items():
        # Menambahkan tanggal ke dictionary
        values['tanggal'] = date
        # Mengubah dictionary menjadi DataFrame dan menambahkannya ke list dfs
        df = pd.DataFrame([values])
        dfs.append(df)

# Menggabungkan semua DataFrame menjadi satu DataFrame besar
merged_df = pd.concat(dfs, ignore_index=True)

# Mengatur ulang urutan kolom
merged_df = merged_df[['tanggal', 'biaya', 'daya', 'kwh', 'timestamp']]
merged_df['tanggal'] = pd.to_datetime(merged_df['tanggal'], format='%d-%m-%Y')
# merged_df['tanggal'] = merged_df['tanggal'].astype('datetime64')


# Tampilkan DataFrame
df=merged_df
df
# Out:
#        tanggal    biaya  daya   kwh timestamp
# 0   2023-12-01  5042.00  2200  3.49  23:59:50
# 1   2023-12-02  5518.75  2200  3.82  23:59:50
# 2   2023-12-03  6255.55  2200  4.33  23:59:50
# 3   2023-12-04  2051.47  2200  1.42  23:59:50
# 4   2023-12-05  2903.85  2200  2.01  23:59:50
# ..         ...      ...   ...   ...       ...
# 117 2024-03-27  3698.43  2200  2.56  23:59:50
# 118 2024-03-28  4218.52  2200  2.92  23:59:50
# 119 2024-03-29  5070.90  2200  3.51  23:59:50
# 120 2024-03-30  5590.99  2200  3.87  23:59:50
# 121 2024-03-31  6226.66  2200  4.31  23:59:50
#
# [122 rows x 5 columns]
# ANJINGGGG : {"date":"2024-04-25T06:42:25.281Z","msg_id":"c781f7ab-fd19-444b-837a-26062fbd879a","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"Hv1rayHFBWWT","outputId":"2f68387a-fb62-4508-cabd-e0c31282f587","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"4ef0b177-0328-44db-ba6b-8ace4d4b166b"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"df.info()"}

# %% [markdown]
# Melihat informasi singkat dari dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tanggal    122 non-null    datetime64[ns]
#  1   biaya      122 non-null    float64
#  2   daya       122 non-null    int64
#  3   kwh        122 non-null    float64
#  4   timestamp  122 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 4.9+ KB
# ANJINGGGG : {"date":"2024-04-25T06:42:27.071Z","msg_id":"0311d4b1-5862-463e-837a-c211254ad30f","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":223},"id":"GqgT4sF1BsVj","outputId":"c8ce08e7-5082-41b3-f34b-44036021c96e","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"8afde226-314e-4fc6-b3d1-bad8f5b0caf7"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print('waktu terawal dari kolom Datetime adalah:', df['tanggal'].min())\ndf.head()\n"}

# %% [markdown]
# Perhatikan waktu terawal dari kolom Datetime dan 5 data teratas dari df

# %%
print('waktu terawal dari kolom Datetime adalah:', df['tanggal'].min())
df.head()
# Out:
# waktu terawal dari kolom Datetime adalah: 2023-12-01 00:00:00
#      tanggal    biaya  daya   kwh timestamp
# 0 2023-12-01  5042.00  2200  3.49  23:59:50
# 1 2023-12-02  5518.75  2200  3.82  23:59:50
# 2 2023-12-03  6255.55  2200  4.33  23:59:50
# 3 2023-12-04  2051.47  2200  1.42  23:59:50
# 4 2023-12-05  2903.85  2200  2.01  23:59:50
# ANJINGGGG : {"date":"2024-04-25T06:42:28.787Z","msg_id":"25fe77e6-5e30-446d-a77a-31375fd9c85f","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":206},"id":"kVbFaI3XBy0j","outputId":"6dde9d7d-1d84-4fc2-b629-9e7c5ec4c3ae","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"9dd84a5c-8148-4ced-8729-c92d4ca3234c"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"# mengurutkan data berdasarkan waktu\ndf.sort_values('tanggal', inplace=True, ignore_index=True)\ndf.head()"}

# %% [markdown]
# Dapat kita lihat bahwa waktu pada baris pertama dari kolom tidak sama dengan waktu terawalnya.
# Maka dari itu perlu kita urutkan df berdasarkan Datetime menggunakan df.sort_values().

# %%
# mengurutkan data berdasarkan waktu
df.sort_values('tanggal', inplace=True, ignore_index=True)
df.head()
# Out:
#      tanggal    biaya  daya   kwh timestamp
# 0 2023-12-01  5042.00  2200  3.49  23:59:50
# 1 2023-12-02  5518.75  2200  3.82  23:59:50
# 2 2023-12-03  6255.55  2200  4.33  23:59:50
# 3 2023-12-04  2051.47  2200  1.42  23:59:50
# 4 2023-12-05  2903.85  2200  2.01  23:59:50
# ANJINGGGG : {"date":"2024-04-25T06:42:32.467Z","msg_id":"35bd9296-302e-481e-a5a3-ff510372c374","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":642},"id":"HFvVrozJB2d7","outputId":"faf242ff-accb-4e93-eab9-3d8a0d8f6a3b","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"3a7998a9-c054-44c1-b12c-d5264fc29cd2"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"plt.figure(figsize=(15,8))\nsns.lineplot(data=df, x='tanggal', y='biaya')"}

# %% [markdown]
# Plot Data df

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df, x='tanggal', y='biaya')
# Out:
# <Axes: xlabel='tanggal', ylabel='biaya'>
# ANJINGGGG : {"date":"2024-04-25T06:42:49.000Z","msg_id":"6ba05211-c02d-4fa1-b52e-6313ad678ea1","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":206},"id":"Nd5TiVowCCTc","outputId":"e2fe5f50-f4fc-41b7-ef3f-73e8ee4c0de8","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"3e431473-015d-4308-ad6a-cb3e3a8c5274"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"df1 = df\ndf1.head()"}

# %%
df1 = df
df1.head()
# Out:
#      tanggal    biaya  daya   kwh timestamp
# 0 2023-12-01  5042.00  2200  3.49  23:59:50
# 1 2023-12-02  5518.75  2200  3.82  23:59:50
# 2 2023-12-03  6255.55  2200  4.33  23:59:50
# 3 2023-12-04  2051.47  2200  1.42  23:59:50
# 4 2023-12-05  2903.85  2200  2.01  23:59:50
# ANJINGGGG : {"date":"2024-04-25T06:42:50.567Z","msg_id":"e96c0089-b732-4d44-b3b7-fe1b1d688e67","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":642},"id":"W03AwUQyCFnc","outputId":"f51ab8e6-5a75-4b11-bf95-297c8a918d3f","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"6a93c0ba-ce3e-4f8d-8f27-e13a10bb8dd6"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"plt.figure(figsize=(15,8))\nsns.lineplot(data=df1, x='tanggal', y='biaya')"}

# %% [markdown]
# Plot Data df1

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1, x='tanggal', y='biaya')
# Out:
# <Axes: xlabel='tanggal', ylabel='biaya'>
# ANJINGGGG : {"date":"2024-04-25T06:42:53.576Z","msg_id":"7922c66a-8618-4102-9c5f-8f05418d8dc2","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":300},"id":"6xi1xBJGCJxL","outputId":"088588e7-538b-4614-e88f-a07cc8b00499","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"b67fe798-81ee-40c6-be44-4ea271591a7c"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"df1.describe()"}

# %% [markdown]
# Melihat Statistika Deskriptif dari Data
# Sebelum melakukan pembuatan model, sebaiknya dilakukan analisa terhadap statistika deskriptif dari data
# Dari statistika deskriptif tersebut, kita dapat meilhat range dari data dan ukuran pusat data

# %%
df1.describe()
# Out:
#              biaya    daya         kwh
# count   122.000000   122.0  122.000000
# mean   4316.574180  2200.0    2.987869
# std    1376.628831     0.0    0.952882
# min    2008.130000  2200.0    1.390000
# 25%    3135.000000  2200.0    2.170000
# 50%    4204.080000  2200.0    2.910000
# 75%    5590.990000  2200.0    3.870000
# max    6457.810000  2200.0    4.470000
# ANJINGGGG : {"date":"2024-04-25T06:42:56.648Z","msg_id":"d0b1fe62-b4c1-410e-9c37-38b9f809dbba","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"KHfYMjrsCS5U","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"4f30c2ae-78fc-43e0-8fb3-21ef6e878be3"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"# split data\ntrain_size = int(len(df1) * 0.8) # Menentukan banyaknya data train yaitu sebesar 70% data\ntrain = df1[:train_size]\ntest =df1[train_size:].reset_index(drop=True)"}

# %% [markdown]
# Dari statistika deskriptif di atas terlihat bahwa data konsumsi biaya listrik cukup besar dan berada pada range 2008 dan 6457 sehingga nanti kita akan lakukan feature scalling menggunakan StandardScaler untuk mengubah distribusi nilai fitur sehingga memiliki rata-rata 0 dan deviasi standar 1.
#
# List normalisasi yang tersedia oleh sklearn : https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html

# %% [markdown]
# ### Split Data
#
#
# Split data dilakukan agar model yang telah dilatih dapat dievaluasi kemampuannya.
# Karena data yang digunakan adalah data time series, maka split data tidak dilakukan secara acak
# Kita juga akan melakukan cross validation menggunakan data train sehingga pastikan data train yang digunakan cukup besar.
# Pada contoh ini kita gunakan 80% baris pertama sebagai data train dan 20% sisanya sebagai data test.

# %%
# split data
train_size = int(len(df1) * 0.8) # Menentukan banyaknya data train yaitu sebesar 70% data
train = df1[:train_size]
test =df1[train_size:].reset_index(drop=True)
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:42:59.619Z","msg_id":"248448d2-282d-448e-84de-69f442e2819d","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"fSGdQdbTF80U","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"4542a2e6-fc1f-4b1d-baac-d9e6923d34cb"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"from sklearn.preprocessing import StandardScaler\nscaler = StandardScaler()\nscaler.fit_transform(train[['biaya']])\n\ntrain['scaled'] = scaler.transform(train[['biaya']])\ntest['scaled'] = scaler.transform(test[['biaya']])"}

# %% [markdown]
# Feature scaling pada `sklearn.preprocessing` berfungsi untuk mengubah skala fitur-fitur dalam dataset sehingga memiliki rentang nilai yang seragam. Tujuan dari feature scaling adalah untuk memastikan bahwa perbedaan dalam skala nilai antar fitur tidak mempengaruhi hasil dari algoritma machine learning yang digunakan. Beberapa algoritma machine learning, seperti regresi linear dan KNN, sensitif terhadap skala fitur. Dengan melakukan feature scaling, kita dapat menghindari masalah ini dan memperbaiki performa model. Beberapa metode feature scaling yang umum digunakan di `sklearn.preprocessing` adalah:
#
# 1. Min-Max Scaling (MinMaxScaler): Mengubah nilai fitur ke dalam rentang tertentu, biasanya 0 hingga 1.
# 2. Standardization (StandardScaler): Mengubah distribusi nilai fitur sehingga memiliki rata-rata 0 dan deviasi standar 1.
# 3. Max Abs Scaling (MaxAbsScaler): Mengubah nilai fitur menjadi rentang -1 hingga 1 berdasarkan nilai absolut maksimum.
# 4. Robust Scaling (RobustScaler): Mengubah nilai fitur berdasarkan median dan interquartile range untuk mengatasi outlier.
#
# Dengan menggunakan feature scaling, kita dapat meningkatkan stabilitas dan konvergensi algoritma machine learning, terutama pada dataset yang memiliki fitur-fitur dengan skala yang berbeda-beda.

# %% [markdown]
# Feature Scalling Menggunakan MinMaxScaler
# MinMaxScaler difit pada data train agar dapat digunakan kembali pada data test maupun data observasi baru.
# Hasil scalling disimpan pada kolom baru yaitu 'scaled'

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(train[['biaya']])

train['scaled'] = scaler.transform(train[['biaya']])
test['scaled'] = scaler.transform(test[['biaya']])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\2164892605.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['scaled'] = scaler.transform(train[['biaya']])
# ANJINGGGG : {"date":"2024-04-25T06:43:06.054Z","msg_id":"ba937643-02d0-4fa6-a36a-4f2acfdcd479","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"UEDXgOd4FAD4","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"511b680c-839d-4117-b7d7-1bf92eb3b89e"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"# from sklearn.preprocessing import MinMaxScaler\n# scaler = MinMaxScaler()\n# scaler.fit(train[['biaya']])\n\n# train['scaled'] = scaler.transform(train[['biaya']])\n# test['scaled'] = scaler.transform(test[['biaya']])"}

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# scaler.fit(train[['biaya']])

# train['scaled'] = scaler.transform(train[['biaya']])
# test['scaled'] = scaler.transform(test[['biaya']])
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:43:09.362Z","msg_id":"5e568822-e7db-4812-9470-57b00e69930d","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":423},"id":"tp0TRDx_CVtd","outputId":"4b7572c2-711a-4e69-cc9e-c5c160522138","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"729cf341-8ea0-4f37-94ca-a9ab7a675075"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"train"}

# %% [markdown]
# Mari kita lihat 5 data pertama pada data train untuk melihat data yang sudah discalling

# %%
train
# Out:
#       tanggal    biaya  daya   kwh timestamp    scaled
# 0  2023-12-01  5042.00  2200  3.49  23:59:50  0.551727
# 1  2023-12-02  5518.75  2200  3.82  23:59:50  0.897949
# 2  2023-12-03  6255.55  2200  4.33  23:59:50  1.433024
# 3  2023-12-04  2051.47  2200  1.42  23:59:50 -1.620038
# 4  2023-12-05  2903.85  2200  2.01  23:59:50 -1.001027
# ..        ...      ...   ...   ...       ...       ...
# 92 2024-03-02  5518.75  2200  3.82  23:59:50  0.897949
# 93 2024-03-03  6270.00  2200  4.34  23:59:50  1.443517
# 94 2024-03-04  2195.94  2200  1.52  23:59:50 -1.515122
# 95 2024-03-05  3077.21  2200  2.13  23:59:50 -0.875131
# 96 2024-03-06  3496.17  2200  2.42  23:59:50 -0.570876
#
# [97 rows x 6 columns]
# ANJINGGGG : {"date":"2024-04-25T06:43:12.105Z","msg_id":"e8040e7d-fde2-4cee-ada7-c554a11629c9","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":833},"id":"Fy3i3NwquK46","outputId":"41d76480-8490-481d-82de-65dcc2cece02","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"304606c4-299f-4574-9e89-8ffc8905c7c0"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"test"}

# %%
test
# Out:
#       tanggal    biaya  daya   kwh timestamp    scaled
# 0  2024-03-07  4261.87  2200  2.95  23:59:50 -0.014814
# 1  2024-03-08  5027.56  2200  3.48  23:59:50  0.541240
# 2  2024-03-09  5677.67  2200  3.93  23:59:50  1.013359
# 3  2024-03-10  6371.13  2200  4.41  23:59:50  1.516960
# 4  2024-03-11  2008.13  2200  1.39  23:59:50 -1.651512
# 5  2024-03-12  3120.55  2200  2.16  23:59:50 -0.843657
# 6  2024-03-13  3669.54  2200  2.54  23:59:50 -0.444973
# 7  2024-03-14  4290.76  2200  2.97  23:59:50  0.006166
# 8  2024-03-15  5042.00  2200  3.49  23:59:50  0.551727
# 9  2024-03-16  5619.88  2200  3.89  23:59:50  0.971391
# 10 2024-03-17  6270.00  2200  4.34  23:59:50  1.443517
# 11 2024-03-18  2008.13  2200  1.39  23:59:50 -1.651512
# 12 2024-03-19  3077.21  2200  2.13  23:59:50 -0.875131
# 13 2024-03-20  3597.30  2200  2.49  23:59:50 -0.497434
# 14 2024-03-21  4175.18  2200  2.89  23:59:50 -0.077770
# 15 2024-03-22  5114.24  2200  3.54  23:59:50  0.604188
# 16 2024-03-23  5533.20  2200  3.83  23:59:50  0.908443
# 17 2024-03-24  6255.55  2200  4.33  23:59:50  1.433024
# 18 2024-03-25  2181.50  2200  1.51  23:59:50 -1.525608
# 19 2024-03-26  3135.00  2200  2.17  23:59:50 -0.833163
# 20 2024-03-27  3698.43  2200  2.56  23:59:50 -0.423992
# 21 2024-03-28  4218.52  2200  2.92  23:59:50 -0.046296
# 22 2024-03-29  5070.90  2200  3.51  23:59:50  0.572714
# 23 2024-03-30  5590.99  2200  3.87  23:59:50  0.950411
# 24 2024-03-31  6226.66  2200  4.31  23:59:50  1.412043
# ANJINGGGG : {"date":"2024-04-25T06:43:16.111Z","msg_id":"1bb100dc-2845-46a1-8e2f-74b563b1c6e9","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"k5m0ck1GCZod","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"21e7ac9a-12d6-48a8-9bc9-869756167c33"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"def sliding_window(data, window_size):\n    sub_seq, next_values = [], []\n    for i in range(len(data)-window_size):\n        sub_seq.append(data[i:i+window_size])\n        next_values.append(data[i+window_size])\n    X = np.stack(sub_seq)\n    y = np.array(next_values)\n    return X,y\n"}

# %% [markdown]
# Membuat fungsi sliding window
# Selanjutnya kita akan membuat fungsi sliding window dengan input data (bertipe data numpy array) dan window size
# Fungsi ini akan menghasilkan variabel input (X) dan variabel target (y)

# %%
def sliding_window(data, window_size):
    sub_seq, next_values = [], []
    for i in range(len(data)-window_size):
        sub_seq.append(data[i:i+window_size])
        next_values.append(data[i+window_size])
    X = np.stack(sub_seq)
    y = np.array(next_values)
    return X,y
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:43:18.232Z","msg_id":"cce1f26f-a5be-428a-9074-01760f0d1027","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"uMa4j0WoCg7d","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"d7ee429d-87c6-4607-877f-77a62bd2e19e"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"window_size = 14\n\nX_train, y_train = sliding_window(train[['scaled']].values, window_size)\nX_test, y_test = sliding_window(test[['scaled']].values, window_size)\n"}

# %% [markdown]
# Berapa window size yang tepat untuk digunakan?
# Pada penerapannya kita dapat menentukan window size berapa saja.
# Untuk mencapai hasil yang maksimal dapat dilakukan percobaan dengan menggunakan beberapa window size.
# Perlu diperhatikan juga bahwa semakin** besar window size **yang digunakan akan memerlukan waktu yang cukup lama dalam proses training data
# Pada contoh ini kita hanya menggunakan window size = 14 atau sama dengan 2 minggu dan kita terapkan pada data train dan test yang telah discalling

# %%
window_size = 14

X_train, y_train = sliding_window(train[['scaled']].values, window_size)
X_test, y_test = sliding_window(test[['scaled']].values, window_size)
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:43:19.994Z","msg_id":"e4b6f28d-45a8-46b7-8b5d-c871920a26cc","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"XBt4-IVkEBqA","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"56660c93-03e7-4620-a41f-74558b0c423e"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print(y_train)"}

# %%
print(y_train)
# Out:
# [[ 0.52025269]
#  [ 0.96090477]
#  [ 1.41204338]
#  [-1.55708222]
#  [-0.82266935]
#  [-0.41349864]
#  [-0.05678237]
#  [ 0.5517268 ]
#  [ 1.07630742]
#  [ 1.54843362]
#  [-1.52560811]
#  [-0.81218282]
#  [-0.40300485]
#  [-0.09875027]
#  [ 0.62516881]
#  [ 0.93991719]
#  [ 1.3910558 ]
#  [-1.58855634]
#  [-0.83316314]
#  [-0.60235057]
#  [-0.09875027]
#  [ 0.5517268 ]
#  [ 1.02385299]
#  [ 1.42252991]
#  [-1.50462779]
#  [-0.83316314]
#  [-0.46596034]
#  [-0.03580205]
#  [ 0.6461564 ]
#  [ 1.0133592 ]
#  [ 1.45400402]
#  [-1.4521661 ]
#  [-0.88562484]
#  [-0.54988888]
#  [-0.15121196]
#  [ 0.5517268 ]
#  [ 1.03434678]
#  [ 1.48548539]
#  [-1.62003771]
#  [-0.89611137]
#  [-0.43448623]
#  [-0.05678237]
#  [ 0.47828479]
#  [ 0.96090477]
#  [ 1.31761378]
#  [-1.63052424]
#  [-0.83316314]
#  [-0.42399243]
#  [ 0.01665965]
#  [ 0.67763051]
#  [ 1.0553271 ]
#  [ 1.41204338]
#  [-1.62003771]
#  [-0.83316314]
#  [-0.58136299]
#  [-0.05678237]
#  [ 0.57271438]
#  [ 0.95041098]
#  [ 1.41204338]
#  [-1.62003771]
#  [-0.89611137]
#  [-0.47644687]
#  [ 0.01665965]
#  [ 0.47828479]
#  [ 0.99237888]
#  [ 1.57990773]
#  [-1.65151182]
#  [-0.88562484]
#  [-0.58136299]
#  [-0.09875027]
#  [ 0.62516881]
#  [ 1.06582089]
#  [ 1.41204338]
#  [-1.56757602]
#  [-0.89611137]
#  [-0.46596034]
#  [-0.07776995]
#  [ 0.6461564 ]
#  [ 0.89794929]
#  [ 1.44351749]
#  [-1.51512158]
#  [-0.87513104]
#  [-0.57087646]]
# ANJINGGGG : {"date":"2024-04-25T06:43:21.424Z","msg_id":"683fd553-369f-4e8d-af2b-80edacce6ff8","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"0zd1D-noD5Vb","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"eb2aa159-1eb8-4f60-a273-65e705f62bcf"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print(X_train)"}

# %%
print(X_train)
# Out:
# [[[ 0.5517268 ]
#   [ 0.89794929]
#   [ 1.4330237 ]
#   ...
#   [-0.88562484]
#   [-0.43448623]
#   [-0.05678237]]
#
#  [[ 0.89794929]
#   [ 1.4330237 ]
#   [-1.62003771]
#   ...
#   [-0.43448623]
#   [-0.05678237]
#   [ 0.52025269]]
#
#  [[ 1.4330237 ]
#   [-1.62003771]
#   [-1.00102749]
#   ...
#   [-0.05678237]
#   [ 0.52025269]
#   [ 0.96090477]]
#
#  ...
#
#  [[-1.65151182]
#   [-0.88562484]
#   [-0.58136299]
#   ...
#   [ 0.6461564 ]
#   [ 0.89794929]
#   [ 1.44351749]]
#
#  [[-0.88562484]
#   [-0.58136299]
#   [-0.09875027]
#   ...
#   [ 0.89794929]
#   [ 1.44351749]
#   [-1.51512158]]
#
#  [[-0.58136299]
#   [-0.09875027]
#   [ 0.62516881]
#   ...
#   [ 1.44351749]
#   [-1.51512158]
#   [-0.87513104]]]
# ANJINGGGG : {"date":"2024-04-25T06:43:22.984Z","msg_id":"b87ddb38-26ca-413a-ad89-ce83d76352ad","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"nuyj2LrxClgL","outputId":"c852f7d3-b0a3-42d1-ca46-83bf5c151c0b","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"d36c510b-1f1a-4bcb-99e4-cb1d4031fc6b"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print(X_train.shape, y_train.shape)\nprint(X_test.shape, y_test.shape)"}

# %% [markdown]
# Penting!!!
# Data input LSTM harus 3D : [samples, timesteps, feature]
# Maka dari itu kita perlu cek dimensi data kita menggunakan np.shape

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (83, 14, 1) (83, 1)
# (11, 14, 1) (11, 1)
# ANJINGGGG : {"date":"2024-04-25T06:43:27.093Z","msg_id":"7e5526e1-d13c-4099-aaa9-e06a1178d250","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"I0w-ohE0Crp8","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"c6e29d82-634c-482f-a6cf-1fd5e6a3a693"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"from tensorflow.keras.models import Sequential\nfrom tensorflow.keras.layers import Dense, Dropout, LSTM #, RNN, GRU"}

# %% [markdown]
# ## LSTM menggunakan Tensorflow dan Keras
# tensorflow: https://www.tensorflow.org/overview
# keras: https://keras.io/about/
#
# Untuk membuat LSTM() layer menggunakan Keras, perhatikan parameter-parameter berikut untuk membuat LSTM layer sederhana, ada beberapa parameter yaitu
#
#
# *   units: menentukan banyaknya LSTM unit
# *   input_shape: menentukan ukuran timesteps dan feature, diperlukan pada layer pertama
# *   return_sequences: jika layer berikutnya berupa LSTM layer maka return_sequences=True (default = False)
#
#
# Paramaeter-parameter lainnya dapat dilihat pada link berikut: https://keras.io/api/layers/recurrent_layers/lstm/

# %% [markdown]
# # Membuat Model Forecasting Menggunakan LSTM
#
# Untuk menggunakan arsitektur GRU, ganti model LSTM dengan RNN atau GRU

# %% [markdown]
# # 1. Import Modul

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM #, RNN, GRU
# Out:
# ANJINGGGG :
# {
#  "date": "2020-07-19T18:35:29-0400",
#  "dirty": false,
#  "error": null,
#  "full-revisionid": "c826bb7df16f470a69f7bf90598fc27586209d11",
#  "version": "v3.3.0"
# }
#
# ANJINGGGG : {
#     "floatx": "float32",
#     "epsilon": 1e-07,
#     "backend": "tensorflow",
#     "image_data_format": "channels_last"
# }
# ANJINGGGG : {
#     "floatx": "float32",
#     "epsilon": 1e-07,
#     "backend": "tensorflow",
#     "image_data_format": "channels_last"
# }
# ANJINGGGG : {"date":"2024-04-25T06:43:30.280Z","msg_id":"7b237169-796b-4e91-a67d-19aff76e4fc3","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"J6G4lwxiC1-U","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"d4e5510c-863b-407f-86e7-412e731496df"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"def create_model(LSTM_unit=64, dropout=0.2): #jika ingin menggunakan RNN atau GRU ganti LSTM dengan GRU/RNN\n    # create model\n    model = Sequential()\n    model.add(LSTM(units=LSTM_unit, input_shape=(window_size, 1)))\n    model.add(Dense(16, activation='relu'))\n    model.add(Dropout(dropout))\n    model.add(Dense(1))\n    # Compile model\n    model.compile(loss='mse', optimizer='adam', metrics=['mae'])\n    return model"}

# %% [markdown]
# # 2. Membuat Fungsi Model Forecasting Menggunakan LSTM
# Fungsi model yang akan dibuat terdiri:
#
# LSTM layer dengan
# * input_shape = (window_size, 1)
# * Dense layer dengan 32 neuron dengan fungsi aktivasi ReLu
# * Dropout antara Dense layer dan Dense output layer
# * Dense output layer dengan 1 neuron
# * loss function yang digunakan adalah Mean Squared Error (MSE)
# * optimizer yang digunakan adalah adam
# * metric yang digunakan adalah Mean Absolute Error (MAE)
#
# * Parameter-parameter yang dijadikan sebagai input dari fungsi tersebut adalah:
#   - LSTM_unit: banyaknya LSTM unit (default = 64)
#   - dropout: persentase dropout (default = 0.2)

# %%
def create_model(LSTM_unit=64, dropout=0.2): #jika ingin menggunakan RNN atau GRU ganti LSTM dengan GRU/RNN
    # create model
    model = Sequential()
    model.add(LSTM(units=LSTM_unit, input_shape=(window_size, 1)))
    model.add(Dense(16, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])
    return model
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:43:32.238Z","msg_id":"bff35158-0d09-4d78-9684-f3832b8daca8","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"hbyF4o95C9-d","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"d6a5500d-8ece-427d-ac1f-237bcd10d483"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"LSTM_unit = [16,32,64,128]\ndropout = [0.1,0.2]\n"}

# %% [markdown]
# #3. Membuat Model
# Kita coba lakukan hypertuning pada parameter, dengan mencoba kombinasi nilai LSTM unitnya 16,32,64,28 dan peluang dropout 0,1 dan 0,2

# %%
LSTM_unit = [16,32,64,128]
dropout = [0.1,0.2]
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:43:40.837Z","msg_id":"2d5698ce-dd70-48eb-93db-17cd5ec7edb2","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"Z_hTx7uKDBfl","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"38ef2792-ac08-4352-b25f-cbd61ff0611d"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"from sklearn.model_selection import GridSearchCV\nfrom tensorflow.keras.wrappers.scikit_learn import KerasRegressor\nfrom tensorflow.keras.callbacks import EarlyStopping\n# Early Stopping\nes = EarlyStopping(monitor = 'val_loss', mode = \"min\", patience = 5, verbose = 0)\n\n# create model\nmodel = KerasRegressor(build_fn=create_model, epochs=150, validation_split=0.1, batch_size=16, verbose=1)\n\n# define the grid search parameters\nLSTM_unit = [16,32,64,128]\ndropout=[0.1,0.2]\nparam_grid = dict(LSTM_unit=LSTM_unit, dropout=dropout)"}

# %% [markdown]
# Selain itu, kita juga gunakan early stopping pada saat proses training

# %%
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping
# Early Stopping
es = EarlyStopping(monitor = 'val_loss', mode = "min", patience = 5, verbose = 0)

# create model
model = KerasRegressor(build_fn=create_model, epochs=150, validation_split=0.1, batch_size=16, verbose=1)

# define the grid search parameters
LSTM_unit = [16,32,64,128]
dropout=[0.1,0.2]
param_grid = dict(LSTM_unit=LSTM_unit, dropout=dropout)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\831021078.py:8: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=150, validation_split=0.1, batch_size=16, verbose=1)
# ANJINGGGG : {"date":"2024-04-25T06:43:48.776Z","msg_id":"d987673c-7e73-4f0a-8106-89f81b8160d8","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"id":"49v9a1fjDJUO","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"3ed95142-4a29-44d8-8f35-98fda11b1420"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=5)"}

# %% [markdown]
# # 4. Membuat Variabel GridSearchCV
# Variabel GridSearchCV dibuat dengan memasukan beberapa parameter yaitu:
# - estimator: model yang ingin dilakukan gridsearch
# - param_grid: parameter yang ingin diuji
# - n_jobs: Jumlah pekerjaan untuk dijalankan secara paralel. (-1 artinya menggunakan seluruh core processor)
# - cv: banyaknya k-fold cross validation

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=5)
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:43:54.642Z","msg_id":"f8189463-20f3-4633-893b-f2440659d9fc","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"OJQpbSVQ0C1c","outputId":"f2adf559-efb9-4572-f414-5a346524e508","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"f7e678f5-bf0c-42e0-9817-a5b45a78932e"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"grid_result = grid.fit(X_train, y_train)"}

# %% [markdown]
# # 5. Training Model dengan GridSearchCV

# %% [markdown]
# #### Non-Anomally

# %%
grid_result = grid.fit(X_train, y_train)
# Out:
# Epoch 1/150
# 5/5 [==============================] - 123s 392ms/step - loss: 1.0119 - mae: 0.8773 - val_loss: 0.8278 - val_mae: 0.8104
# Epoch 2/150
# 5/5 [==============================] - 0s 36ms/step - loss: 0.9498 - mae: 0.8486 - val_loss: 0.7802 - val_mae: 0.7912
# Epoch 3/150
# 5/5 [==============================] - 0s 38ms/step - loss: 0.8779 - mae: 0.8182 - val_loss: 0.7206 - val_mae: 0.7651
# Epoch 4/150
# 5/5 [==============================] - 0s 36ms/step - loss: 0.7912 - mae: 0.7714 - val_loss: 0.6516 - val_mae: 0.7267
# Epoch 5/150
# 5/5 [==============================] - 0s 42ms/step - loss: 0.7019 - mae: 0.7177 - val_loss: 0.5691 - val_mae: 0.6670
# Epoch 6/150
# 5/5 [==============================] - 0s 37ms/step - loss: 0.6040 - mae: 0.6664 - val_loss: 0.4444 - val_mae: 0.5847
# Epoch 7/150
# 5/5 [==============================] - 0s 41ms/step - loss: 0.5489 - mae: 0.6111 - val_loss: 0.2965 - val_mae: 0.4565
# Epoch 8/150
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4363 - mae: 0.4990 - val_loss: 0.2885 - val_mae: 0.3539
# Epoch 9/150
# 5/5 [==============================] - 0s 46ms/step - loss: 0.2860 - mae: 0.3683 - val_loss: 0.1087 - val_mae: 0.2943
# Epoch 10/150
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2784 - mae: 0.3544 - val_loss: 0.1219 - val_mae: 0.3335
# Epoch 11/150
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1228 - mae: 0.3030 - val_loss: 0.0980 - val_mae: 0.2851
# Epoch 12/150
# 5/5 [==============================] - 0s 44ms/step - loss: 0.1360 - mae: 0.2850 - val_loss: 0.0752 - val_mae: 0.2379
# Epoch 13/150
# 5/5 [==============================] - 0s 47ms/step - loss: 0.
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0209 - mae: 0.1092 - val_loss: 0.0054 - val_mae: 0.0633
# Epoch 147/150
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0157 - mae: 0.0886 - val_loss: 0.0078 - val_mae: 0.0809
# Epoch 148/150
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0286 - mae: 0.1149 - val_loss: 0.0054 - val_mae: 0.0612
# Epoch 149/150
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0209 - mae: 0.1084 - val_loss: 0.0049 - val_mae: 0.0556
# Epoch 150/150
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0217 - mae: 0.1222 - val_loss: 0.0053 - val_mae: 0.0646
# ANJINGGGG : {"date":"2024-04-25T06:52:38.899Z","msg_id":"1fcc42a0-fa36-445e-b436-9865c74fafec","msg_type":"kernel_info_request","session":"170c0c96-a14b-44ef-8c56-832f1823b13d","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {}
# ANJINGGGG : {}

# %% [markdown]
# #### Anomally

# %%
grid_result = grid.fit(X_train, y_train)
# Out:
# Epoch 1/150
# 5/5 [==============================] - 4s 176ms/step - loss: 0.9884 - mae: 0.8627 - val_loss: 0.8183 - val_mae: 0.8022
# Epoch 2/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.9234 - mae: 0.8318 - val_loss: 0.7489 - val_mae: 0.7646
# Epoch 3/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.8604 - mae: 0.7975 - val_loss: 0.6608 - val_mae: 0.7137
# Epoch 4/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.7493 - mae: 0.7384 - val_loss: 0.5447 - val_mae: 0.6350
# Epoch 5/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6204 - mae: 0.6545 - val_loss: 0.4022 - val_mae: 0.5239
# Epoch 6/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4613 - mae: 0.5433 - val_loss: 0.2967 - val_mae: 0.4471
# Epoch 7/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3736 - mae: 0.4761 - val_loss: 0.1533 - val_mae: 0.2716
# Epoch 8/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2428 - mae: 0.3722 - val_loss: 0.0844 - val_mae: 0.2452
# Epoch 9/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2052 - mae: 0.3565 - val_loss: 0.0493 - val_mae: 0.1734
# Epoch 10/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1595 - mae: 0.2862 - val_loss: 0.0528 - val_mae: 0.1735
# Epoch 11/150
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1454 - mae: 0.2947 - val_loss: 0.0619 - val_mae: 0.1927
# Epoch 12/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1470 - mae: 0.3059 - val_loss: 0.0693 - val_mae: 0.2248
# Epoch 13/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1300 - mae: 0.2991 - val_loss: 0.0317 - val_mae: 0.1495
# Epoch 14/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1029 - mae: 0.2342 - val_loss: 0.0193 - val_mae: 0.1163
# Epoch 15/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1003 - mae: 0.2472 - val_loss: 0.0281 - val_mae: 0.1304
# Epoch 16/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1316 - mae: 0.2854 - val_loss: 0.0106 - val_mae: 0.0746
# Epoch 17/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0805 - mae: 0.2111 - val_loss: 0.0212 - val_mae: 0.1037
# Epoch 18/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0855 - mae: 0.2279 - val_loss: 0.0154 - val_mae: 0.1040
# Epoch 19/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0973 - mae: 0.2120 - val_loss: 0.0157 - val_mae: 0.1193
# Epoch 20/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0869 - mae: 0.2156 - val_loss: 0.0229 - val_mae: 0.1248
# Epoch 21/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0804 - mae: 0.2040 - val_loss: 0.0113 - val_mae: 0.0866
# Epoch 22/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0651 - mae: 0.1733 - val_loss: 0.0147 - val_mae: 0.1018
# Epoch 23/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1084 - mae: 0.2437 - val_loss: 0.0198 - val_mae: 0.1100
# Epoch 24/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0597 - mae: 0.1818 - val_loss: 0.0087 - val_mae: 0.0713
# Epoch 25/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0661 - mae: 0.1871 - val_loss: 0.0100 - val_mae: 0.0790
# Epoch
150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0356 - mae: 0.1324 - val_loss: 0.0061 - val_mae: 0.0615
# Epoch 128/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0411 - mae: 0.1455 - val_loss: 0.0079 - val_mae: 0.0686
# Epoch 129/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0380 - mae: 0.1271 - val_loss: 0.0053 - val_mae: 0.0610
# Epoch 130/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0325 - mae: 0.1306 - val_loss: 0.0080 - val_mae: 0.0757
# Epoch 131/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0255 - mae: 0.1193 - val_loss: 0.0142 - val_mae: 0.0980
# Epoch 132/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0293 - mae: 0.1229 - val_loss: 0.0085 - val_mae: 0.0810
# Epoch 133/150
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0316 - mae: 0.1274 - val_loss: 0.0077 - val_mae: 0.0762
# Epoch 134/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0377 - mae: 0.1441 - val_loss: 0.0093 - val_mae: 0.0762
# Epoch 135/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0408 - mae: 0.1354 - val_loss: 0.0059 - val_mae: 0.0644
# Epoch 136/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0256 - mae: 0.1159 - val_loss: 0.0088 - val_mae: 0.0824
# Epoch 137/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0339 - mae: 0.1413 - val_loss: 0.0103 - val_mae: 0.0795
# Epoch 138/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0618 - mae: 0.1706 - val_loss: 0.0080 - val_mae: 0.0686
# Epoch 139/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0268 - mae: 0.1209 - val_loss: 0.0063 - val_mae: 0.0600
# Epoch 140/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0339 - mae: 0.1269 - val_loss: 0.0059 - val_mae: 0.0649
# Epoch 141/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0398 - mae: 0.1322 - val_loss: 0.0098 - val_mae: 0.0741
# Epoch 142/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0336 - mae: 0.1272 - val_loss: 0.0100 - val_mae: 0.0899
# Epoch 143/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0320 - mae: 0.1121 - val_loss: 0.0086 - val_mae: 0.0793
# Epoch 144/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0405 - mae: 0.1296 - val_loss: 0.0062 - val_mae: 0.0647
# Epoch 145/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0385 - mae: 0.1326 - val_loss: 0.0063 - val_mae: 0.0647
# Epoch 146/150
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0244 - mae: 0.1170 - val_loss: 0.0087 - val_mae: 0.0744
# Epoch 147/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0309 - mae: 0.1169 - val_loss: 0.0084 - val_mae: 0.0773
# Epoch 148/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0327 - mae: 0.1311 - val_loss: 0.0089 - val_mae: 0.0766
# Epoch 149/150
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0425 - mae: 0.1490 - val_loss: 0.0068 - val_mae: 0.0694
# Epoch 150/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0484 - mae: 0.1474 - val_loss: 0.0073 - val_mae: 0.0671

# %% [markdown]
# # 6. Melihat Hasil Parameter Terbaik

# %% [markdown]
# #### Non-Anomally

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Mengambil model terbaik
best_model = grid_result.best_estimator_.model
# Out:
# Best: -0.009968 using {'LSTM_unit': 128, 'dropout': 0.1}
# -0.010612 (0.005671) with: {'LSTM_unit': 16, 'dropout': 0.1}
# -0.014363 (0.004422) with: {'LSTM_unit': 16, 'dropout': 0.2}
# -0.012390 (0.006250) with: {'LSTM_unit': 32, 'dropout': 0.1}
# -0.012575 (0.008055) with: {'LSTM_unit': 32, 'dropout': 0.2}
# -0.010683 (0.005825) with: {'LSTM_unit': 64, 'dropout': 0.1}
# -0.017531 (0.006671) with: {'LSTM_unit': 64, 'dropout': 0.2}
# -0.009968 (0.003698) with: {'LSTM_unit': 128, 'dropout': 0.1}
# -0.010825 (0.003747) with: {'LSTM_unit': 128, 'dropout': 0.2}
# ANJINGGGG : {"date":"2024-04-25T06:54:29.866Z","msg_id":"736b5245-a7c0-409d-a5d8-32b1b802deb7","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":497},"id":"rGaWcypy3TaZ","outputId":"f6e369e4-92c7-4ebb-a567-8460dedf56f9","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"4b0994eb-5d58-47a8-978c-22df838c0599"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"history = best_model.history\n# grafik loss function MSE\n\nplt.plot(history.history['loss'], label='Training loss')\nplt.plot(history.history['val_loss'], label='Validation loss')\nplt.title('loss function MSE')\nplt.ylabel('MSE')\nplt.xlabel('Epoch')\nplt.legend()"}

# %% [markdown]
# Dari Hasil Training menggunakan GridSearchCV, kita peroleh:
#
# parameter terbaiknya adalah: **{'LSTM_unit': 128, 'dropout': 0.2}**
# Rata-rata Loss Function dari hasil Cross Validation adalah **0.004190**
# Kemudian coba kita lihat grafik loss function MSE dan metric MAE terhadap epoch untuk melihat performa model terbaik kita dengan cara sebagai berikut
#
# Kita dapat melihat grafik loss function MSE dan metric MAE terhadap epoch untuk melihat performa model kita dengan cara sebagai berikut

# %%
history = best_model.history
# grafik loss function MSE

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('loss function MSE')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend()
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:54:36.496Z","msg_id":"7b2280a2-18d2-4433-93cd-32d049c030d9","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":497},"id":"a_3jmJfa39Du","outputId":"2ff1c278-dbc1-4680-908e-f9116eb06f50","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"6e6bf152-cad2-499f-9f15-1e535d7bd17f"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"# grafik metric MAE\n\nplt.plot(history.history['mae'], label='Training MAE')\nplt.plot(history.history['val_mae'], label='Validation MAE')\nplt.title('metric MAE')\nplt.ylabel('MAE')\nplt.xlabel('Epoch')\nplt.legend()"}

# %%
# grafik metric MAE

plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('metric MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend()
# Out:
# ANJINGGGG : {"date":"2024-04-25T06:54:42.058Z","msg_id":"3fdac374-65bd-43a2-b08e-3dd310e67d0d","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"Rw2XDusN0nvB","outputId":"820e68f4-3323-4938-f04b-cd2645d2a4a6","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"1c9685f4-df63-424c-b5bc-1b1ed346eece"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"# Prediksi data train\npredict_train = scaler.inverse_transform(best_model.predict(X_train))\ntrue_train = scaler.inverse_transform(y_train)\n\n# Prediksi data test\npredict_test = scaler.inverse_transform(best_model.predict(X_test))\ntrue_test = scaler.inverse_transform(y_test)"}

# %% [markdown]
# #### Anomally

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Mengambil model terbaik
best_model = grid_result.best_estimator_.model
# Out:
# Best: -0.020286 using {'LSTM_unit': 128, 'dropout': 0.1}
# -0.050553 (0.074522) with: {'LSTM_unit': 16, 'dropout': 0.1}
# -0.028855 (0.023550) with: {'LSTM_unit': 16, 'dropout': 0.2}
# -0.040070 (0.050918) with: {'LSTM_unit': 32, 'dropout': 0.1}
# -0.024078 (0.019175) with: {'LSTM_unit': 32, 'dropout': 0.2}
# -0.022752 (0.025340) with: {'LSTM_unit': 64, 'dropout': 0.1}
# -0.022350 (0.017929) with: {'LSTM_unit': 64, 'dropout': 0.2}
# -0.020286 (0.016316) with: {'LSTM_unit': 128, 'dropout': 0.1}
# -0.025394 (0.022279) with: {'LSTM_unit': 128, 'dropout': 0.2}

# %% [markdown]
# Dari Hasil Training menggunakan GridSearchCV, kita peroleh:
#
# parameter terbaiknya adalah: **{'LSTM_unit': 32, 'dropout': 0.1}**
# Rata-rata Loss Function dari hasil Cross Validation adalah **0.014447**
# Kemudian coba kita lihat grafik loss function MSE dan metric MAE terhadap epoch untuk melihat performa model terbaik kita dengan cara sebagai berikut
#
# Kita dapat melihat grafik loss function MSE dan metric MAE terhadap epoch untuk melihat performa model kita dengan cara sebagai berikut

# %%
history = best_model.history
# grafik loss function MSE

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('loss function MSE')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend()

# %%
# grafik metric MAE

plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('metric MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend()

# %% [markdown]
# # 7. Evaluasi Model
# Melakukan prediksi pada data train dan data test

# %% [markdown]
# #### Non-Anomally

# %%
# Prediksi data train
predict_train = scaler.inverse_transform(best_model.predict(X_train))
true_train = scaler.inverse_transform(y_train)

# Prediksi data test
predict_test = scaler.inverse_transform(best_model.predict(X_test))
true_test = scaler.inverse_transform(y_test)
# Out:
# 3/3 [==============================] - 2s 9ms/step
# 1/1 [==============================] - 0s 59ms/step
# ANJINGGGG : {"date":"2024-04-25T06:54:47.228Z","msg_id":"866635e6-ea6c-4b61-8434-492cbc02767f","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"m1kmRTUF0nvC","outputId":"10da682f-baf2-4e10-9933-16c78dea0b37","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"7ea6b893-a623-469d-b3ce-1e994e856bf7"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print(len(predict_train))"}

# %%
print(len(predict_train))
# Out:
# 83
# ANJINGGGG : {"date":"2024-04-25T06:54:51.469Z","msg_id":"d6f7e66f-c524-421c-97c7-deb2147e8029","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":674},"id":"AE4tM6Ws0nvD","outputId":"c81bb0c4-12d5-4def-bbad-38fcc8378dc6","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"f7ca7779-c2be-49cd-b984-c35280c0f76b"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"train['predict'] = np.nan\ntrain['predict'][-len(predict_train):] = predict_train[:,0]\n\nplt.figure(figsize=(15,8))\nsns.lineplot(data=train, x='tanggal', y='biaya', label = 'train')\nsns.lineplot(data=train, x='tanggal', y='predict', label = 'predict')"}

# %% [markdown]
# Plot prediksi data train

# %%
train['predict'] = np.nan
train['predict'][-len(predict_train):] = predict_train[:,0]

plt.figure(figsize=(15,8))
sns.lineplot(data=train, x='tanggal', y='biaya', label = 'train')
sns.lineplot(data=train, x='tanggal', y='predict', label = 'predict')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\2412743260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['predict'] = np.nan
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\2412743260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['predict'][-len(predict_train):] = predict_train[:,0]
# <Axes: xlabel='tanggal', ylabel='biaya'>
# ANJINGGGG : {"date":"2024-04-25T06:54:59.367Z","msg_id":"50fb424c-4edc-4e7f-9202-abe69ed4cc0f","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"k5HIPYKn0nvD","outputId":"6437e348-677d-49e8-8d30-217f3a9efb9e","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"22a732dc-7743-4179-83a0-4758d3521a58"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print(train['biaya'])"}

# %%
print(train['biaya'])
# Out:
# 0     5042.00
# 1     5518.75
# 2     6255.55
# 3     2051.47
# 4     2903.85
#        ...
# 92    5518.75
# 93    6270.00
# 94    2195.94
# 95    3077.21
# 96    3496.17
# Name: biaya, Length: 97, dtype: float64
# ANJINGGGG : {"date":"2024-04-25T06:55:03.926Z","msg_id":"45fb3c17-5614-43d5-99a8-eb2aa1539c27","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":655},"id":"_rXssvKE0nvD","outputId":"abcfdf85-8f25-4eef-9257-c90aa1a6a24c","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"b440e25a-8c4d-4382-9e55-fa3bd4efdee3"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"train['predict'] = np.nan\ntrain['predict'][-len(predict_train):] = predict_train[:,0]\n\nevaluate = train\nevaluate['difference'] = evaluate['predict'] - evaluate['biaya']\n\n\nplt.figure(figsize=(15,8))\n# sns.lineplot(data=train, x='tanggal', y='biaya', label = 'train')\nsns.barplot(data=evaluate[-len(predict_train):], x='tanggal', y='difference', label = 'difference')"}

# %%
train['predict'] = np.nan
train['predict'][-len(predict_train):] = predict_train[:,0]

evaluate = train
evaluate['difference'] = evaluate['predict'] - evaluate['biaya']


plt.figure(figsize=(15,8))
# sns.lineplot(data=train, x='tanggal', y='biaya', label = 'train')
sns.barplot(data=evaluate[-len(predict_train):], x='tanggal', y='difference', label = 'difference')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\321314863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['predict'] = np.nan
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\321314863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['predict'][-len(predict_train):] = predict_train[:,0]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\321314863.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   evaluate['difference'] = evaluate['predict'] - evaluate['biaya']
# <Axes: xlabel='tanggal', ylabel='difference'>
# ANJINGGGG : {"date":"2024-04-25T06:55:13.944Z","msg_id":"43095bbe-f826-47d3-8d04-8428b575acfd","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"ohye5jn60nvD","outputId":"9b5303b9-6922-43aa-db93-7f232b74f712","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"c56d27e9-b319-4791-ad76-14a54b689db2"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"print(f\"rata-rata selisih : {evaluate['difference'].sum()/len(evaluate['difference'])}\")\n"}

# %%
print(f"rata-rata selisih : {evaluate['difference'].sum()/len(evaluate['difference'])}")
# Out:
# rata-rata selisih : -2.7290793129832287
# ANJINGGGG : {"date":"2024-04-25T06:55:23.756Z","msg_id":"bb853162-c2c6-40c9-866b-40b5d9b19c91","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/","height":657},"id":"qfIEyWSF0nvE","outputId":"7efb2333-bd0a-4828-bbf2-1ef8c58c3094","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"8c815aa5-4e32-4230-b9a8-f6144873c781"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"test['predict'] = np.nan\ntest['predict'][-len(predict_test):] = predict_test[:,0]\n\nplt.figure(figsize=(15,8))\nsns.lineplot(data=test, x='tanggal', y='biaya', label = 'test')\nsns.lineplot(data=test, x='tanggal', y='predict', label = 'predict')"}

# %% [markdown]
# Plot prediksi data test

# %%
test['predict'] = np.nan
test['predict'][-len(predict_test):] = predict_test[:,0]

plt.figure(figsize=(15,8))
sns.lineplot(data=test, x='tanggal', y='biaya', label = 'test')
sns.lineplot(data=test, x='tanggal', y='predict', label = 'predict')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11800\2737737851.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predict'][-len(predict_test):] = predict_test[:,0]
# <Axes: xlabel='tanggal', ylabel='biaya'>
# ANJINGGGG : {"date":"2024-04-25T06:55:40.827Z","msg_id":"ec93059a-f19e-4966-8cfe-28c9704e40fa","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"OcrT1q56_i9R","outputId":"1cce079b-d66a-4262-c642-134d98d5f45b","trusted":false,"deletedCells":[],"recordTiming":false,"cellId":"4aa4ab8d-eeae-4ed8-9aef-62f63f257b4e"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"import pickle\n\n# Nama file untuk menyimpan data pickle\nfile_pickle = 'best_model.pkl'\n\n# Menyimpan variabel ke dalam file pickle\nwith open(file_pickle, 'wb') as file:\n    pickle.dump(best_model, file)\n\nprint('Variabel telah disimpan dalam file pickle.')\n"}

# %% [markdown]
# #### Anomally

# %%
# Prediksi data train
predict_train = scaler.inverse_transform(best_model.predict(X_train))
true_train = scaler.inverse_transform(y_train)

# Prediksi data test
predict_test = scaler.inverse_transform(best_model.predict(X_test))
true_test = scaler.inverse_transform(y_test)
# Out:
# 3/3 [==============================] - 1s 13ms/step
# 1/1 [==============================] - 0s 61ms/step

# %%
print(len(predict_train))
# Out:
# 83

# %% [markdown]
# Plot prediksi data train

# %%
train['predict'] = np.nan
train['predict'][-len(predict_train):] = predict_train[:,0]

plt.figure(figsize=(15,8))
sns.lineplot(data=train, x='tanggal', y='biaya', label = 'train')
sns.lineplot(data=train, x='tanggal', y='predict', label = 'predict')
# Out:
# <Axes: xlabel='tanggal', ylabel='biaya'>

# %%
print(train['biaya'])
# Out:
# 0     5042.00
# 1     5518.75
# 2     6255.55
# 3     2051.47
# 4     2903.85
#        ...
# 92    5518.75
# 93    6270.00
# 94    2195.94
# 95    3077.21
# 96    3496.17
# Name: biaya, Length: 97, dtype: float64

# %%
train['predict'] = np.nan
train['predict'][-len(predict_train):] = predict_train[:,0]

evaluate = train
evaluate['difference'] = evaluate['predict'] - evaluate['biaya']


plt.figure(figsize=(15,8))
# sns.lineplot(data=train, x='tanggal', y='biaya', label = 'train')
sns.barplot(data=evaluate, x='tanggal', y='difference', label = 'difference')
# Out:
# <Axes: xlabel='tanggal', ylabel='difference'>

# %%
print(f"rata-rata selisih : {evaluate['difference'].sum()/len(evaluate['difference'])}")
# Out:
# rata-rata selisih : 19.897203507570893

# %% [markdown]
# Plot prediksi data test

# %%
test['predict'] = np.nan
test['predict'][-len(predict_test):] = predict_test[:,0]

plt.figure(figsize=(15,8))
sns.lineplot(data=test, x='tanggal', y='biaya', label = 'test')
sns.lineplot(data=test, x='tanggal', y='predict', label = 'predict')
# Out:
# <Axes: xlabel='tanggal', ylabel='biaya'>

# %% [markdown]
# Plot prediksi data test sebulan terakhir

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=test[-12:], x='tanggal', y='biaya', label = 'test')
sns.lineplot(data=test[-12:], x='tanggal', y='predict', label = 'predict')
# Out:
# <Axes: xlabel='tanggal', ylabel='biaya'>

# %%
import pickle

# Nama file untuk menyimpan data pickle
file_pickle = 'test.pkl'

# Menyimpan variabel ke dalam file pickle
with open(file_pickle, 'wb') as file:
    pickle.dump(test, file)

print('Variabel telah disimpan dalam file pickle.')
# Out:
# Variabel telah disimpan dalam file pickle.

# %%
# # Membuka kembali file pickle
# with open(file_pickle, 'rb') as file:
#     loaded_data = pickle.load(file)

# # Menampilkan variabel yang diambil kembali
# print('Data yang diambil kembali dari file pickle:')
# print(loaded_data)

# %% [markdown]
# Melakukan forecasting

# %%
# @title **AI Forecasting electricity costs**

#@markdown ---
#@markdown Silahkan anda masukan jumlah hari kedepan yang ingin diramalkan :

n_future = "30" #@param {type:"string"}

# forecasting data selanjutnya
y_train = scaler.transform(train[['biaya']])
n_future = int(n_future) # hari kedepan
future = [[y_train[-1,0]]]
X_new = y_train[-window_size:,0].tolist()

for i in range(n_future):
    y_future = best_model.predict(np.array([X_new]).reshape(1,window_size,1))
    future.append([y_future[0,0]])
    X_new = X_new[1:]
    X_new.append(y_future[0,0])

future = scaler.inverse_transform(np.array(future))
date_future = pd.date_range(start=train['tanggal'].values[-1], periods=n_future+1, freq='D')
# print(date_future)

# Plot Data sebulan terakhir dan seminggu ke depan
plt.figure(figsize=(15,5))
sns.lineplot(data=train, x='tanggal', y='biaya', label = 'test')
sns.lineplot(data=train, x='tanggal', y='predict', label = 'predict')
sns.lineplot(x=date_future, y=future[:,0], label = 'future')
plt.ylabel('biaya');

print(f"Besaran biaya selama {n_future} hari sebelumnya sebesar : \033[1mRp.{'{:,.0f}'.format(int(sum(train['biaya'][-n_future:]))).replace(',', '.')},-\033[0m")
print(f"Forecasting kisaran biaya selama {n_future} hari kedepan sebesar : \033[1mRp.{'{:,.0f}'.format(int(sum(future[:,0]))).replace(',', '.')},-\033[0m")
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# Besaran biaya selama 30 hari sebelumnya sebesar : Rp.126.324,-
# Forecasting kisaran biaya selama 30 hari kedepan sebesar : Rp.136.605,-

# %%
import pickle

file_pickle = 'best_model.pkl'

# Membuka kembali file pickle
with open(file_pickle, 'rb') as file:
    model_test = pickle.load(file)

# # Menampilkan variabel yang diambil kembali
# print('Data yang diambil kembali dari file pickle:')
# print(best_model) ==3.7.1
# Out:
# ANJINGGGG : {"module": "keras", "class_name": "Sequential", "config": {"name": "sequential", "layers": [{"class_name": "InputLayer", "config": {"batch_input_shape": [null, 14, 1], "dtype": "float32", "sparse": false, "ragged": false, "name": "lstm_input"}}, {"class_name": "LSTM", "config": {"name": "lstm", "trainable": true, "dtype": "float32", "batch_input_shape": [null, 14, 1], "return_sequences": false, "return_state": false, "go_backwards": false, "stateful": false, "unroll": false, "time_major": false, "units": 128, "activation": "tanh", "recurrent_activation": "sigmoid", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "recurrent_initializer": {"class_name": "Orthogonal", "config": {"gain": 1.0, "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "unit_forget_bias": true, "kernel_regularizer": null, "recurrent_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "recurrent_constraint": null, "bias_constraint": null, "dropout": 0.0, "recurrent_dropout": 0.0, "implementation": 2}}, {"class_name": "Dense", "config": {"name": "dense", "trainable": true, "dtype": "float32", "units": 16, "activation": "relu", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Dropout", "config": {"name": "dropout", "trainable": true, "dtype": "float32", "rate": 0.1, "noise_shape": null, "seed": null}}, {"class_name": "Dense", "config": {"name": "dense_1", "trainable": true, "dtype": "float32", "units": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}]}, "registered_name": null, "build_config": {"input_shape": [null, 14, 1]}, "compile_config": {"optimizer": "adam", "loss": "mse", "metrics": ["mae"], "loss_weights": null, "weighted_metrics": null, "run_eagerly": null, "steps_per_execution": null, "jit_compile": null}}
# ANJINGGGG : {"date":"2024-04-25T07:01:10.211Z","msg_id":"76d5a935-2fe0-4c68-a4f1-2e5ac8d60aa5","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"trusted":true,"deletedCells":[],"recordTiming":false,"cellId":"70dba78f-5979-44ec-b284-62c4f97c89a3"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"# @title **AI Forecasting electricity costs**\n\n#@markdown ---\n#@markdown Silahkan anda masukan jumlah hari kedepan yang ingin diramalkan :\n\nn_future = \"30\" #@param {type:\"string\"}\n\n# forecasting data selanjutnya\ny_train = scaler.transform(train[['biaya']])\nn_future = int(n_future) # hari kedepan\nfuture = [[y_train[-1,0]]]\nX_new = y_train[-window_size:,0].tolist()\n\nfor i in range(n_future):\n    y_future = best_model.predict(np.array([X_new]).reshape(1,window_size,1))\n    future.append([y_future[0,0]])\n    X_new = X_new[1:]\n    X_new.append(y_future[0,0])\n\nfuture = scaler.inverse_transform(np.array(future))\ndate_future = pd.date_range(start=train['tanggal'].values[-1], periods=n_future+1, freq='D')\n# print(date_future)\n\n# Plot Data sebulan terakhir dan seminggu ke depan\nplt.figure(figsize=(15,5))\nsns.lineplot(data=train, x='tanggal', y='biaya', label = 'test')\nsns.lineplot(data=train, x='tanggal', y='predict', label = 'predict')\nsns.lineplot(x=date_future, y=future[:,0], label = 'future')\nplt.ylabel('biaya');\n\nprint(f\"Besaran biaya selama {n_future} hari sebelumnya sebesar : \\033Rp.{'{:,.0f}'.format(int(sum(train['biaya'][-n_future:]))).replace(',', '.')},-\\033\")\nprint(f\"Forecasting kisaran biaya selama {n_future} hari kedepan sebesar : \\033Rp.{'{:,.0f}'.format(int(sum(future[:,0]))).replace(',', '.')},-\\033\")\n"}

# %%
# @title **AI Forecasting electricity costs**

#@markdown ---
#@markdown Silahkan anda masukan jumlah hari kedepan yang ingin diramalkan :

n_future = "30" #@param {type:"string"}

# forecasting data selanjutnya
y_train = scaler.transform(train[['biaya']])
n_future = int(n_future) # hari kedepan
future = [[y_train[-1,0]]]
X_new = y_train[-window_size:,0].tolist()

for i in range(n_future):
    y_future = model_test.predict(np.array([X_new]).reshape(1,window_size,1))
    future.append([y_future[0,0]])
    X_new = X_new[1:]
    X_new.append(y_future[0,0])

future = scaler.inverse_transform(np.array(future))
date_future = pd.date_range(start=train['tanggal'].values[-1], periods=n_future+1, freq='D')
# print(date_future)

# Plot Data sebulan terakhir dan seminggu ke depan
plt.figure(figsize=(15,5))
sns.lineplot(data=train, x='tanggal', y='biaya', label = 'test')
sns.lineplot(data=train, x='tanggal', y='predict', label = 'predict')
sns.lineplot(x=date_future, y=future[:,0], label = 'future')
plt.ylabel('biaya');

print(f"Besaran biaya selama {n_future} hari sebelumnya sebesar : \033[1mRp.{'{:,.0f}'.format(int(sum(train['biaya'][-n_future:]))).replace(',', '.')},-\033[0m")
print(f"Forecasting kisaran biaya selama {n_future} hari kedepan sebesar : \033[1mRp.{'{:,.0f}'.format(int(sum(future[:,0]))).replace(',', '.')},-\033[0m")
# Out:
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# Besaran biaya selama 30 hari sebelumnya sebesar : Rp.126.324,-
# Forecasting kisaran biaya selama 30 hari kedepan sebesar : Rp.133.019,-
# ANJINGGGG : {"date":"2024-04-25T07:06:36.039Z","msg_id":"8417a6a9-e8ee-4d05-a00e-2c8598e48eb1","msg_type":"execute_request","session":"5070bf4f-65a6-461e-9c09-0be7261b98fe","username":"","version":"5.2"}
# ANJINGGGG : {}
# ANJINGGGG : {"colab":{"base_uri":"https://localhost:8080/"},"id":"OcrT1q56_i9R","outputId":"1cce079b-d66a-4262-c642-134d98d5f45b","trusted":true,"deletedCells":[],"recordTiming":false,"cellId":"4aa4ab8d-eeae-4ed8-9aef-62f63f257b4e"}
# ANJINGGGG : {"silent":false,"store_history":true,"user_expressions":{},"allow_stdin":true,"stop_on_error":true,"code":"import pickle\n\n# Nama file untuk menyimpan data pickle\nfile_pickle = 'train.pkl'\n\n# Menyimpan variabel ke dalam file pickle\nwith open(file_pickle, 'wb') as file:\n    pickle.dump(train, file)\n\nprint('Variabel telah disimpan dalam file pickle.')\n"}
